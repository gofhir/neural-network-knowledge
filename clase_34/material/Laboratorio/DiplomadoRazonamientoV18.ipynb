# %% [markdown]
# # Laboratorio Razonamiento - Diplomado IA Educacion Continua UC

# %%
# !pip install torch==2.11.0 torchvision==0.26.0 torchaudio==2.11.0 --index-url https://download.pytorch.org/whl/cu128

# !pip install accelerate==1.14.0 \
    einops==0.8.2 \
    evaluate==0.4.6 \
    gdown==5.2.2 \
    liger-kernel==0.8.0 \
    ml_dtypes==0.5.4 \
    nltk==3.9.1 \
    numpy==2.0.2 \
    packaging==26.2 \
    pandas==2.2.2 \
    peft==0.19.1 \
    torchao==0.17.0 \
    torchdata==0.11.0 \
    torchsummary==1.5.1 \
    torchtune==0.6.1 \
    tqdm==4.67.3 \
    transformers==5.12.1 \
    trl==1.7.1 \
    rapidfuzz==3.14.5 \
    dspy==3.2.1 \
    bitsandbytes==0.49.2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Requirement already satisfied: torch==2.11.0 in /usr/local/lib/python3.12/dist-packages (2.11.0+cu128)
# Requirement already satisfied: torchvision==0.26.0 in /usr/local/lib/python3.12/dist-packages (0.26.0+cu128)
# Requirement already satisfied: torchaudio==2.11.0 in /usr/local/lib/python3.12/dist-packages (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0) (3.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.26.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.26.0) (11.3.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch==2.11.0) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.11.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.11.0) (3.0.3)
# Requirement already satisfied: accelerate==1.14.0 in /usr/local/lib/python3.12/dist-packages (1.14.0)
# Requirement already satisfied: einops==0.8.2 in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Collecting evaluate==0.4.6
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: gdown==5.2.2 in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Collecting liger-kernel==0.8.0
#   Downloading liger_kernel-0.8.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: ml_dtypes==0.5.4 in /usr/local/lib/python3.12/dist-packages (0.5.4)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: packaging==26.2 in /usr/local/lib/python3.12/dist-packages (26.2)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: peft==0.19.1 in /usr/local/lib/python3.12/dist-packages (0.19.1)
# Collecting torchao==0.17.0
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: torchdata==0.11.0 in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: torchsummary==1.5.1 in /usr/local/lib/python3.12/dist-packages (1.5.1)
# Requirement already satisfied: torchtune==0.6.1 in /usr/local/lib/python3.12/dist-packages (0.6.1)
# Requirement already satisfied: tqdm==4.67.3 in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: transformers==5.12.1 in /usr/local/lib/python3.12/dist-packages (5.12.1)
# Collecting trl==1.7.1
#   Downloading trl-1.7.1-py3-none-any.whl.metadata (11 kB)
# Collecting rapidfuzz==3.14.5
#   Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting dspy==3.2.1
#   Downloading dspy-3.2.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting bitsandbytes==0.49.2
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==1.14.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate==1.14.0) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.14.0) (2.11.0+cu128)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.14.0) (1.20.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.14.0) (0.8.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.6) (4.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.6) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.6) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.6) (3.7.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.6) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate==0.4.6) (2025.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown==5.2.2) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown==5.2.2) (3.29.4)
# Requirement already satisfied: triton>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from liger-kernel==0.8.0) (3.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2026.2)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.12/dist-packages (from torchdata==0.11.0) (2.5.0)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (from torchtune==0.6.1) (1.0.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from torchtune==0.6.1) (0.2.1)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from torchtune==0.6.1) (0.13.0)
# Requirement already satisfied: blobfile>=2 in /usr/local/lib/python3.12/dist-packages (from torchtune==0.6.1) (3.2.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from torchtune==0.6.1) (0.22.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from torchtune==0.6.1) (2.3.1)
# Requirement already satisfied: Pillow>=9.4.0 in /usr/local/lib/python3.12/dist-packages (from torchtune==0.6.1) (11.3.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers==5.12.1) (0.25.1)
# Collecting datasets>=2.0.0 (from evaluate==0.4.6)
#   Downloading datasets-5.0.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from trl==1.7.1) (3.1.6)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy==3.2.1) (2.43.0)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy==3.2.1) (3.11.9)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy==3.2.1) (2.13.4)
# Collecting litellm>=1.64.0 (from dspy==3.2.1)
#   Downloading litellm-1.91.0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 4.3 MB/s eta 0:00:00
# Collecting diskcache>=5.6.0 (from dspy==3.2.1)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting json-repair>=0.54.2 (from dspy==3.2.1)
#   Downloading json_repair-0.61.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy==3.2.1) (9.1.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy==3.2.1) (4.14.0)
# Collecting asyncer==0.0.8 (from dspy==3.2.1)
#   Downloading asyncer-0.0.8-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy==3.2.1) (6.2.6)
# Requirement already satisfied: cloudpickle>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from dspy==3.2.1) (3.1.2)
# Collecting gepa==0.0.27 (from gepa[dspy]==0.0.27->dspy==3.2.1)
#   Downloading gepa-0.0.27-py3-none-any.whl.metadata (30 kB)
# Collecting typeguard==4.4.3 (from dspy==3.2.1)
#   Downloading typeguard-4.4.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: typing_extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from typeguard==4.4.3->dspy==3.2.1) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy==3.2.1) (3.18)
# Requirement already satisfied: pycryptodomex>=3.8 in /usr/local/lib/python3.12/dist-packages (from blobfile>=2->torchtune==0.6.1) (3.23.0)
# Requirement already satisfied: lxml>=4.9 in /usr/local/lib/python3.12/dist-packages (from blobfile>=2->torchtune==0.6.1) (6.1.1)
# Collecting pyarrow>=21.0.0 (from datasets>=2.0.0->evaluate==0.4.6)
#   Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate==0.4.6) (0.28.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate==0.4.6) (3.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate==1.14.0) (1.5.1)
# Collecting fastuuid<1.0,>=0.14.0 (from litellm>=1.64.0->dspy==3.2.1)
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.2.1) (1.2.2)
# Collecting importlib-metadata<9.0,>=8.0.0 (from litellm>=1.64.0->dspy==3.2.1)
#   Downloading importlib_metadata-8.9.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.2.1) (4.26.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->trl==1.7.1) (3.0.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy==3.2.1) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy==3.2.1) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy==3.2.1) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy==3.2.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy==3.2.1) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy==3.2.1) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate==0.4.6) (3.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate==0.4.6) (2026.6.17)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0) (3.4.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0) (12.8.90)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers==5.12.1) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers==5.12.1) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers==5.12.1) (0.0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown==5.2.2) (2.8.4)
# WARNING: huggingface-hub 1.20.1 does not provide the extra 'hf-transfer'
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in /usr/local/lib/python3.12/dist-packages (from kagglehub->torchtune==0.6.1) (0.1.23)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->torchtune==0.6.1) (4.9.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==5.2.2) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6) (1.24.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->accelerate==1.14.0) (1.5.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate==0.4.6) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate==0.4.6) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9.0,>=8.0.0->litellm>=1.64.0->dspy==3.2.1) (4.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy==3.2.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy==3.2.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy==3.2.1) (2026.5.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kagglesdk<1.0,>=0.1.22->kagglehub->torchtune==0.6.1) (5.29.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers==5.12.1) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers==5.12.1) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate==1.14.0) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers==5.12.1) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.3 MB/s eta 0:00:00
# Downloading liger_kernel-0.8.0-py3-none-any.whl (403 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.1/403.1 kB 41.6 MB/s eta 0:00:00
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 120.4 MB/s eta 0:00:00
# Downloading trl-1.7.1-py3-none-any.whl (842 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 842.4/842.4 kB 65.3 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 124.0 MB/s eta 0:00:00
# Downloading dspy-3.2.1-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.0/331.0 kB 36.8 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.1 MB/s eta 0:00:00
# Downloading asyncer-0.0.8-py3-none-any.whl (9.2 kB)
# Downloading gepa-0.0.27-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.5/146.5 kB 18.6 MB/s eta 0:00:00
# Downloading typeguard-4.4.3-py3-none-any.whl (34 kB)
# Downloading datasets-5.0.0-py3-none-any.whl (555 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 53.3 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.8 MB/s eta 0:00:00
# Downloading json_repair-0.61.2-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 6.2 MB/s eta 0:00:00
# Downloading litellm-1.91.0-py3-none-any.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 130.3 MB/s eta 0:00:00
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 28.9 MB/s eta 0:00:00
# Downloading importlib_metadata-8.9.0-py3-none-any.whl (27 kB)
# Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (48.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 56.8 MB/s eta 0:00:00
# Installing collected packages: torchao, typeguard, rapidfuzz, pyarrow, json-repair, importlib-metadata, gepa, fastuuid, diskcache, asyncer, liger-kernel, datasets, bitsandbytes, litellm, evaluate, trl, dspy
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.5.2
#     Uninstalling typeguard-4.5.2:
#       Successfully uninstalled typeguard-4.5.2
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 9.0.0
#     Uninstalling importlib_metadata-9.0.0:
#       Successfully uninstalled importlib_metadata-9.0.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed asyncer-0.0.8 bitsandbytes-0.49.2 datasets-5.0.0 diskcache-5.6.3 dspy-3.2.1 evaluate-0.4.6 fastuuid-0.14.0 gepa-0.0.27 importlib-metadata-8.9.0 json-repair-0.61.2 liger-kernel-0.8.0 litellm-1.91.0 pyarrow-24.0.0 rapidfuzz-3.14.5 torchao-0.17.0 trl-1.7.1 typeguard-4.4.3

# %%
# !gdown 1wGcNYF4tqXb7j20IWJibzdTO0dyfeUyj
# !gdown 1YlHIj-8eVCdDglIrPju4uw1OGwBwacNq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wGcNYF4tqXb7j20IWJibzdTO0dyfeUyj
# To: /content/conversations_qw_3_6p_2.zip
# 100% 5.04M/5.04M [00:00<00:00, 29.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YlHIj-8eVCdDglIrPju4uw1OGwBwacNq
# To: /content/dict_A_to_I.txt
# 100% 8.98M/8.98M [00:00<00:00, 44.1MB/s]

# %%
# !unzip conversations_qw_3_6p_2.zip
# Out:
# Archive:  conversations_qw_3_6p_2.zip
#    creating: conversations_qw_3_6p_2/
#   inflating: __MACOSX/._conversations_qw_3_6p_2
#   inflating: conversations_qw_3_6p_2/conversation_416_The_girl_looked_for.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_416_The_girl_looked_for.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_117_Yes__I_eat_chili.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_117_Yes__I_eat_chili.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_309_She_hugged_me.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_309_She_hugged_me.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_514_Do_you_like_Japanese.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_514_Do_you_like_Japanese.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_551_I_am_a_cat.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_551_I_am_a_cat.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_235_I_come.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_235_I_come.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_388_Daniel_is_whistling.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_388_Daniel_is_whistling.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_374_It_s_not_a_computer.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_374_It_s_not_a_computer.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_219_Thank_you.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_219_Thank_you.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_437_What_do_you_really_t.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_437_What_do_you_really_t.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_067_I_have_a_cat.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_067_I_have_a_cat.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_410_I_m_not_giving_the_c.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_410_I_m_not_giving_the_c.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_178_I_am_wearing_underwe.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_178_I_am_wearing_underwe.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_172_He_will_be_back_at_t.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_172_He_will_be_back_at_t.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_520_The_table_is_painted.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_520_The_table_is_painted.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_043_I_cooked_up_the_salm.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_043_I_cooked_up_the_salm.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_295_This_corn_is_fresh.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_295_This_corn_is_fresh.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_460_The_boy_is_working.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_460_The_boy_is_working.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_150_Put_the_corn_bread_o.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_150_Put_the_corn_bread_o.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_287_I_looked_for_the_gir.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_287_I_looked_for_the_gir.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_369_Where_is_the_restroo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_369_Where_is_the_restroo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_556_You_don_t_remember.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_556_You_don_t_remember.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_062_What_are_you_worryin.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_062_What_are_you_worryin.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_510_How_is_your_dad.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_510_How_is_your_dad.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_057_I_come_from_Trondhei.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_057_I_come_from_Trondhei.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_412_I_m_reading_a_book.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_412_I_m_reading_a_book.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_242_The_pencil_is_small.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_242_The_pencil_is_small.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_463_Where_is_Tom.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_463_Where_is_Tom.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_448_He_is_waiting_for_yo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_448_He_is_waiting_for_yo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_044_I_want_to_learn_Hawa.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_044_I_want_to_learn_Hawa.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_554_Why.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_554_Why.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_318_I_was_struck_by_a_fl.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_318_I_was_struck_by_a_fl.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_023_Hello__Tom.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_023_Hello__Tom.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_122_He__she_or_they_tied.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_122_He__she_or_they_tied.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_137_I_was_three_years_ol.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_137_I_was_three_years_ol.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_426_I_am_from_Oslo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_426_I_am_from_Oslo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_429_Meztli_likes_the_moo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_429_Meztli_likes_the_moo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_376_The_book_is_on_the_t.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_376_The_book_is_on_the_t.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_515_This_dog_is_big.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_515_This_dog_is_big.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_547_I_m_not_old.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_547_I_m_not_old.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_480_She_comes.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_480_She_comes.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_428_The_apple_is_on_the.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_428_The_apple_is_on_the.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_479_My_name_is_Jack.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_479_My_name_is_Jack.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_115_Even_you_are_a_guy_w.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_115_Even_you_are_a_guy_w.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_532_What_kind_of_fruit_i.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_532_What_kind_of_fruit_i.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_329_Is_your_dad_having_f.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_329_Is_your_dad_having_f.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_419_I_like_the_color_gra.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_419_I_like_the_color_gra.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_407_That_is_an_elk.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_407_That_is_an_elk.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_397_It_is_necessary_that.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_397_It_is_necessary_that.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_081_I_don_t_see_the_chil.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_081_I_don_t_see_the_chil.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_159_Was_their_mother_wat.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_159_Was_their_mother_wat.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_003_Are_you_going_to_sin.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_003_Are_you_going_to_sin.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_233_You_ll_learn_a_lot_h.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_233_You_ll_learn_a_lot_h.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_260_Tom_has_three_daught.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_260_Tom_has_three_daught.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_121_Give_Tom_the_keys.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_121_Give_Tom_the_keys.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_489_You_have_everything.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_489_You_have_everything.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_518_Everyone_always_spea.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_518_Everyone_always_spea.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_378_The_bread_is_fresh.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_378_The_bread_is_fresh.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_082_That_is_a_deer.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_082_That_is_a_deer.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_214_The_wind_is_strong.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_214_The_wind_is_strong.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_110_I_smell_something_bu.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_110_I_smell_something_bu.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_345_All_lizards_can_lay.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_345_All_lizards_can_lay.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_247_He_found_me_a_good_j.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_247_He_found_me_a_good_j.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_438_Do_you_want_anything.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_438_Do_you_want_anything.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_491_She_feeds_me.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_491_She_feeds_me.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_051_Can_you_think_of_any.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_051_Can_you_think_of_any.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_167_You_re_not_a_woman.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_167_You_re_not_a_woman.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_573_What_time_does_the_b.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_573_What_time_does_the_b.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_497_Hello_Kaʻiulani.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_497_Hello_Kaʻiulani.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_095_They_shot_the_deer.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_095_They_shot_the_deer.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_383_He_is_going_to_die.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_383_He_is_going_to_die.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_085_I_am_a_woman.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_085_I_am_a_woman.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_074_Tom_has_three_childr.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_074_Tom_has_three_childr.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_535_You_drink_tea.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_535_You_drink_tea.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_152_What_is_your_name.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_152_What_is_your_name.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_568_What_do_you_want_to.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_568_What_do_you_want_to.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_486_How_is_your_mother.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_486_How_is_your_mother.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_231_I_m_the_teacher.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_231_I_m_the_teacher.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_471_I_found_the_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_471_I_found_the_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_147_You_must_go_home.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_147_You_must_go_home.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_381_Who_are_you.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_381_Who_are_you.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_408_Since_I_m_a_Florida.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_408_Since_I_m_a_Florida.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_327_I_eat.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_327_I_eat.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_230_He_gave_the_dog_to_t.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_230_He_gave_the_dog_to_t.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_308_No__thank_you.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_308_No__thank_you.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_522_The_child_is_eating.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_522_The_child_is_eating.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_215_What_are_your_dogs.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_215_What_are_your_dogs.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_567_Hi__How_are_you.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_567_Hi__How_are_you.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_042_Well__I_guess_we_sho.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_042_Well__I_guess_we_sho.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_275_The_man_reportedly_r.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_275_The_man_reportedly_r.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_384_I_want_to_eat_French.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_384_I_want_to_eat_French.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_341_She_owns_a_lot_of_cl.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_341_She_owns_a_lot_of_cl.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_130_Take_a_jacket.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_130_Take_a_jacket.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_409_She_is_intimidated_b.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_409_She_is_intimidated_b.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_045_The_main_is_running.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_045_The_main_is_running.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_192_The_boys_are_working.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_192_The_boys_are_working.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_002_The_house_was_full_o.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_002_The_house_was_full_o.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_151_The_pig_is_growing_f.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_151_The_pig_is_growing_f.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_370_Do_you_have_anything.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_370_Do_you_have_anything.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_261_Those_things_belong.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_261_Those_things_belong.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_052_Where_is_Tom_s_house.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_052_Where_is_Tom_s_house.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_464_Tom_has_three_older.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_464_Tom_has_three_older.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_252_I_m_singing_the_chil.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_252_I_m_singing_the_chil.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_128_Can_you_call_and_ask.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_128_Can_you_call_and_ask.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_431_This_book_is_green.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_431_This_book_is_green.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_210_You_are_Simon__son_o.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_210_You_are_Simon__son_o.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_472_You_ll_see_the_stude.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_472_You_ll_see_the_stude.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_109_We_come.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_109_We_come.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_453_Take_a_sweater.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_453_Take_a_sweater.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_533_The_folks_heading_ba.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_533_The_folks_heading_ba.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_348_I_bought_a_house_rec.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_348_I_bought_a_house_rec.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_015_This_is_a_green_appl.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_015_This_is_a_green_appl.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_245_Tom_has_three_thousa.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_245_Tom_has_three_thousa.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_223_I_know_some_of_the_b.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_223_I_know_some_of_the_b.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_048_The_room_is_dark.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_048_The_room_is_dark.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_181_The_girls_work.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_181_The_girls_work.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_300_This_is_an_apple.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_300_This_is_an_apple.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_499_Everyone_should_be_a.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_499_Everyone_should_be_a.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_019_The_color_of_my_skir.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_019_The_color_of_my_skir.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_387_Those_are_moving.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_387_Those_are_moving.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_198_Maybe_it_won_t_rain.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_198_Maybe_it_won_t_rain.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_538_My_grandmother_wears.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_538_My_grandmother_wears.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_371_Pua_is_going_to_sing.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_371_Pua_is_going_to_sing.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_405_You_re_an_engineer.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_405_You_re_an_engineer.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_274_I_m_not_smart.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_274_I_m_not_smart.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_320_Natives_wear_moccasi.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_320_Natives_wear_moccasi.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_222_You_ve_never_been_to.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_222_You_ve_never_been_to.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_529_How_are_you____I_am.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_529_How_are_you____I_am.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_343_I_have_two_books.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_343_I_have_two_books.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_091_I_am_going_to_Gjoa_H.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_091_I_am_going_to_Gjoa_H.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_326_I_feel_sorry.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_326_I_feel_sorry.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_580_I_live_in_Honolulu.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_580_I_live_in_Honolulu.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_090_She_gave_the_dog_to.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_090_She_gave_the_dog_to.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_182_What_s_going_to_happ.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_182_What_s_going_to_happ.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_456_People_are_weird.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_456_People_are_weird.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_283_You_have_many_books.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_283_You_have_many_books.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_389_I_live_in_Oslo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_389_I_live_in_Oslo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_216_That_s_very_helpful.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_216_That_s_very_helpful.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_461_She_found_the_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_461_She_found_the_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_171_It_s_a_child_that_is.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_171_It_s_a_child_that_is.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_541_I_love_you.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_541_I_love_you.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_566_He_was_terribly_poor.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_566_He_was_terribly_poor.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_468_How_many_sisters_do.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_468_How_many_sisters_do.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_269_Let_s_party.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_269_Let_s_party.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_359_I_used_a_ladle_to_st.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_359_I_used_a_ladle_to_st.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_281_Can_you_meet_with_me.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_281_Can_you_meet_with_me.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_243_He_uses_an_axe_to_sp.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_243_He_uses_an_axe_to_sp.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_454_It_doesn_t_hurt.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_454_It_doesn_t_hurt.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_572_Good_afternoon.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_572_Good_afternoon.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_094_Thanks_for_letting_m.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_094_Thanks_for_letting_m.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_390_He_goes_to_junior_hi.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_390_He_goes_to_junior_hi.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_073_This_is_a_newspaper.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_073_This_is_a_newspaper.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_379_The_dog_is_behind_th.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_379_The_dog_is_behind_th.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_495_It_s_meat_that_the_c.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_495_It_s_meat_that_the_c.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_505_He_shot_the_deer.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_505_He_shot_the_deer.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_131_How_do_you_say_XXX_i.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_131_How_do_you_say_XXX_i.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_441_I_am_married_and_I_h.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_441_I_am_married_and_I_h.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_508_I_want_the_book.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_508_I_want_the_book.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_204_You_made_an_error.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_204_You_made_an_error.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_301_He_remembered_what_I.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_301_He_remembered_what_I.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_362_I_tied_up_the_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_362_I_tied_up_the_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_311_I_will_come.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_311_I_will_come.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_113_I_m_a_man.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_113_I_m_a_man.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_562_Is_it_far.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_562_Is_it_far.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_433_Which_dog_is_yours.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_433_Which_dog_is_yours.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_097_Her_broach_is_amethy.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_097_Her_broach_is_amethy.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_116_I_have_two_brothers.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_116_I_have_two_brothers.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_417_I_am_sick.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_417_I_am_sick.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_196_He_tied_up_the_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_196_He_tied_up_the_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_317_I_don_t_like_math.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_317_I_don_t_like_math.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_458_I_want_ice_cream.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_458_I_want_ice_cream.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_191_Pua_is_singing_at_ch.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_191_Pua_is_singing_at_ch.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_288_A_raccoon_is_looking.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_288_A_raccoon_is_looking.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_394_No_way.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_394_No_way.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_011_Do_you_know_if_Lucy.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_011_Do_you_know_if_Lucy.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_070_Good_evening.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_070_Good_evening.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_136_There_is_no_Nobel_Pr.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_136_There_is_no_Nobel_Pr.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_099_The_color_of_my_shoe.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_099_The_color_of_my_shoe.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_424_He_is_gone_for_the_w.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_424_He_is_gone_for_the_w.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_382_What_time_is_it.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_382_What_time_is_it.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_418_The_man_isn_t_runnin.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_418_The_man_isn_t_runnin.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_506_It_is_a_bird.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_506_It_is_a_bird.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_474_He_feeds_me.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_474_He_feeds_me.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_203_I_am_Tom.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_203_I_am_Tom.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_559_I_m_not_a_teacher.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_559_I_m_not_a_teacher.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_240_I_was_found_by_the_d.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_240_I_was_found_by_the_d.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_053_How_far_is_it_to_the.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_053_How_far_is_it_to_the.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_187_Nobody_wants_a_war.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_187_Nobody_wants_a_war.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_352_His_relatives_are_ga.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_352_His_relatives_are_ga.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_413_How_many_languages_d.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_413_How_many_languages_d.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_027_They_come.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_027_They_come.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_338_They_all_ate_the_foo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_338_They_all_ate_the_foo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_315_Burj_Khalifa_is_curr.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_315_Burj_Khalifa_is_curr.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_132_The_man_is_strong.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_132_The_man_is_strong.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_183_This_dog_is_white.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_183_This_dog_is_white.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_065_Tom_has_three_months.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_065_Tom_has_three_months.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_563_Are_you_all_on_the_s.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_563_Are_you_all_on_the_s.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_325_I_am_fourteen_years.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_325_I_am_fourteen_years.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_530_How_far_are_we_going.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_530_How_far_are_we_going.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_184_As_for_the_child__he.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_184_As_for_the_child__he.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_284_I_hug_myself.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_284_I_hug_myself.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_033_Are_you_content_with.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_033_Are_you_content_with.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_444_What_is_your_tribal.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_444_What_is_your_tribal.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_452_He_found_the_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_452_He_found_the_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_340_Your_father_is_tall.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_340_Your_father_is_tall.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_077_I_don_t_want_to_go_t.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_077_I_don_t_want_to_go_t.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_037_Are_you_happy.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_037_Are_you_happy.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_013_I_m_a_child.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_013_I_m_a_child.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_285_You_must_finish_this.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_285_You_must_finish_this.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_133_I_don_t_have_a_cat.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_133_I_don_t_have_a_cat.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_101_Armenia_is_called__H.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_101_Armenia_is_called__H.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_258_Are_you_listening_to.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_258_Are_you_listening_to.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_253_This_is_a_pear.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_253_This_is_a_pear.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_025_The_dog_is_dying.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_025_The_dog_is_dying.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_569_Pua_is_singing.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_569_Pua_is_singing.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_291_I_don_t_understand.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_291_I_don_t_understand.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_176_The_horse_has_brown.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_176_The_horse_has_brown.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_220_Speak__Kawika.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_220_Speak__Kawika.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_414_The_girl_hugs_me.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_414_The_girl_hugs_me.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_367_Where_do_you_live.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_367_Where_do_you_live.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_425_That_s_all_I_do_here.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_425_That_s_all_I_do_here.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_527_No__my_name_is_not_M.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_527_No__my_name_is_not_M.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_360_This_is_your_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_360_This_is_your_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_473_Hello__my_friend__Ho.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_473_Hello__my_friend__Ho.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_395_Are_you_afraid_of_it.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_395_Are_you_afraid_of_it.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_483_I_love_you__Laurie.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_483_I_love_you__Laurie.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_224_What_do_you_have_to.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_224_What_do_you_have_to.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_328_What_I_gave_him_is_o.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_328_What_I_gave_him_is_o.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_440_Tom_has_three_older.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_440_Tom_has_three_older.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_399_A_foal_was_born.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_399_A_foal_was_born.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_357_I_like_the_taste_of.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_357_I_like_the_taste_of.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_298_I_hit_him_or_her_wit.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_298_I_hit_him_or_her_wit.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_393_Do_you_like_the_musi.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_393_Do_you_like_the_musi.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_481_One__two__three__fou.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_481_One__two__three__fou.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_331_I_can_t.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_331_I_can_t.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_526_He_is_my_heart.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_526_He_is_my_heart.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_492_The_bus_is_long.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_492_The_bus_is_long.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_186_Is_it_a_bird.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_186_Is_it_a_bird.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_356_They_hugged_themselv.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_356_They_hugged_themselv.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_089_He_looked_for_the_gi.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_089_He_looked_for_the_gi.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_206_Tom_has_three_millio.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_206_Tom_has_three_millio.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_276_I_am_going_to_make_a.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_276_I_am_going_to_make_a.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_055_You_should_talk_to_t.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_055_You_should_talk_to_t.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_445_Tom_has_three_nieces.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_445_Tom_has_three_nieces.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_112_You_have_to_speak_En.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_112_You_have_to_speak_En.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_427_I_am_a_girl.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_427_I_am_a_girl.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_282_I_m_a_woman.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_282_I_m_a_woman.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_455_They_tied_up_the_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_455_They_tied_up_the_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_026_I_want_to_go_to_Aust.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_026_I_want_to_go_to_Aust.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_251_See_you_soon.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_251_See_you_soon.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_047_She_is_a_good_studen.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_047_She_is_a_good_studen.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_141_The_ball_is_round.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_141_The_ball_is_round.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_368_She_was_listening.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_368_She_was_listening.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_124_Where.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_124_Where.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_517_Are_you_interested_i.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_517_Are_you_interested_i.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_211_You_re_not_a_man.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_211_You_re_not_a_man.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_436_Do_you_have_any_anim.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_436_Do_you_have_any_anim.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_321_That_is_a_mink.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_321_That_is_a_mink.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_564_It_was_nothing.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_564_It_was_nothing.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_324_The_man_wearing_a_ha.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_324_The_man_wearing_a_ha.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_305_My_name_is_Tom.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_305_My_name_is_Tom.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_006_He_was_listening.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_006_He_was_listening.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_009_It_sounds_like_a_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_009_It_sounds_like_a_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_168_I_m_Seminole.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_168_I_m_Seminole.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_161_I_went_to_the_bank.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_161_I_went_to_the_bank.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_319_The_belt_is_made_of.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_319_The_belt_is_made_of.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_262_I_was_away_all_week.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_262_I_was_away_all_week.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_030_Woof__woof__woof.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_030_Woof__woof__woof.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_503_Goodbye.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_503_Goodbye.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_443_A_strong_wind_was_bl.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_443_A_strong_wind_was_bl.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_072_I_want_to_go_to_coll.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_072_I_want_to_go_to_coll.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_332_I_m_from_Skagit.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_332_I_m_from_Skagit.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_273_She_called_you_yeste.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_273_She_called_you_yeste.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_430_My_father_is_tall.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_430_My_father_is_tall.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_336_My_name_s_Tom.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_336_My_name_s_Tom.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_337_You_are_on_top_of_th.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_337_You_are_on_top_of_th.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_118_I_m_sorry__I_don_t_u.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_118_I_m_sorry__I_don_t_u.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_519_Do_you_know_how_to_s.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_519_Do_you_know_how_to_s.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_164_Tom_has_three_cats.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_164_Tom_has_three_cats.jsonl
# ...
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_021_We_looked_for_the_do.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_162_I_m_giving_the_dog_m.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_162_I_m_giving_the_dog_m.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_238_I_drink_coffee.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_238_I_drink_coffee.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_265_Some_things_just_can.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_265_Some_things_just_can.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_166_This_is_a_horse.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_166_This_is_a_horse.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_155_I_have_two_cars.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_155_I_have_two_cars.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_160_Pua_is_going_to_sing.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_160_Pua_is_going_to_sing.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_446_Who_are_your_people.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_446_Who_are_your_people.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_363_Good.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_363_Good.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_199_I_am_working.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_199_I_am_working.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_138_This_is_a_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_138_This_is_a_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_153_Their_car_is_not_goo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_153_Their_car_is_not_goo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_404_Good_morning.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_404_Good_morning.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_064_With_whom_does_José.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_064_With_whom_does_José.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_391_They_haven_t_arrived.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_391_They_haven_t_arrived.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_310_We_drink_everything.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_310_We_drink_everything.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_537_Can_you_hear_anythin.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_537_Can_you_hear_anythin.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_482_I_want_to_go_to_Kyot.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_482_I_want_to_go_to_Kyot.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_402_The_girl_looked_for.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_402_The_girl_looked_for.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_449_I_m_an_engineer.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_449_I_m_an_engineer.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_579_Pua_sings.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_579_Pua_sings.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_578_Today_is_January_2nd.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_578_Today_is_January_2nd.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_193_I_m_glad_I_m_not_a_w.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_193_I_m_glad_I_m_not_a_w.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_466_Is_it_a_chair.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_466_Is_it_a_chair.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_396_I_feed_myself.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_396_I_feed_myself.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_524_The_chairs_are_under.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_524_The_chairs_are_under.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_313_They_re_doctors.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_313_They_re_doctors.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_398_Even_when_she_s_not.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_398_Even_when_she_s_not.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_100_I_have_thirteen_cats.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_100_I_have_thirteen_cats.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_511_Where_are_you_from.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_511_Where_are_you_from.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_212_The_sun_sets.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_212_The_sun_sets.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_142_What_do_you_want_to.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_142_What_do_you_want_to.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_439_I_shot_the_deer.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_439_I_shot_the_deer.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_316_What_are_you_all_doi.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_316_What_are_you_all_doi.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_024_You_all_come.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_024_You_all_come.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_175_Use_a_comb_to_comb_y.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_175_Use_a_comb_to_comb_y.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_123_They_found_the_dog.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_123_They_found_the_dog.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_271_I_have_two_cats.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_271_I_have_two_cats.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_200_That_is_a_bear.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_200_That_is_a_bear.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_330_It_is_a_chair.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_330_It_is_a_chair.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_385_I_will_work_hard.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_385_I_will_work_hard.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_545_She_cooked_the_salmo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_545_She_cooked_the_salmo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_119_You_should_be_the_on.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_119_You_should_be_the_on.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_346_She_gave_something_t.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_346_She_gave_something_t.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_350_I_used_a_spoon_to_ea.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_350_I_used_a_spoon_to_ea.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_488_Are_you_sleepy.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_488_Are_you_sleepy.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_069_I_hit_him_or_her_wit.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_069_I_hit_him_or_her_wit.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_560_Is_the_dog_swimming.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_560_Is_the_dog_swimming.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_561_The_boy_looks_for_a.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_561_The_boy_looks_for_a.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_234_I_live_on_the_Bright.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_234_I_live_on_the_Bright.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_259_I_m_from_the_wind_cl.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_259_I_m_from_the_wind_cl.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_093_The_whale_is_the_lar.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_093_The_whale_is_the_lar.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_250_Hello__what_is_your.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_250_Hello__what_is_your.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_334_She_asked_me_how_old.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_334_She_asked_me_how_old.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_525_She_will_be_back_at.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_525_She_will_be_back_at.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_297_What_are_they_doing.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_297_What_are_they_doing.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_246_Let_s_go_to_my_house.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_246_Let_s_go_to_my_house.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_107_I_lost_my_hat.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_107_I_lost_my_hat.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_098_Go__Kaʻiulani.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_098_Go__Kaʻiulani.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_087_The_dog_was_looked_f.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_087_The_dog_was_looked_f.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_227_I_m_thirsty.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_227_I_m_thirsty.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_239_I_do_not_have_any_mo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_239_I_do_not_have_any_mo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_217_Thanks.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_217_Thanks.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_475_Are_you_playing_socc.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_475_Are_you_playing_socc.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_157_Hi__my_name_s_Tom.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_157_Hi__my_name_s_Tom.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_422_Yesterday_he_went_ca.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_422_Yesterday_he_went_ca.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_467_The_girl_hugged_hers.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_467_The_girl_hugged_hers.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_386_He_s_trying_to_lure.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_386_He_s_trying_to_lure.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_303_You_should_write_you.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_303_You_should_write_you.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_179_It_won_t_amount_to_a.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_179_It_won_t_amount_to_a.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_498_My_tongue_is_swollen.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_498_My_tongue_is_swollen.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_306_I_m_going_to_a_store.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_306_I_m_going_to_a_store.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_366_Are_you_hungry.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_366_Are_you_hungry.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_536_There_are_tables_at.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_536_There_are_tables_at.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_170_Are_you_studying_Eng.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_170_Are_you_studying_Eng.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_548_She_s_a_good_woman.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_548_She_s_a_good_woman.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_442_I_m_hungry.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_442_I_m_hungry.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_344_I_ve_spent_a_week_in.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_344_I_ve_spent_a_week_in.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_411_We_are_gathered.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_411_We_are_gathered.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_507_The_chef_wears_an_ap.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_507_The_chef_wears_an_ap.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_209_Winter_is_coming.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_209_Winter_is_coming.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_257_We_saw_the_boy_that.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_257_We_saw_the_boy_that.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_061_Hello.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_061_Hello.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_490_Allow_me_to_go_with.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_490_Allow_me_to_go_with.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_423_You_should_call_your.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_423_You_should_call_your.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_521_Who_killed_the_mule.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_521_Who_killed_the_mule.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_036_You_look_busy.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_036_You_look_busy.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_173_Goodbye.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_173_Goodbye.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_059_I_m_Ricardo.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_059_I_m_Ricardo.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_307_The_dog_growled.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_307_The_dog_growled.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_415_I_love_you.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_415_I_love_you.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_280_The_old_woman_dried.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_280_The_old_woman_dried.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_185_I_m_Tom.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_185_I_m_Tom.jsonl
#   inflating: conversations_qw_3_6p_2/conversation_029_She_looked_for_the_g.jsonl
#   inflating: __MACOSX/conversations_qw_3_6p_2/._conversation_029_She_looked_for_the_g.jsonl

# %% [markdown]
# # Uso de herramientas
#
# Vamos a darle a un modelo la capacidad de usar un diccionario del idioma Lakota, y vamos a pedirle que lo utilice para realizar traducciones desde el ingles.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import json
import re
import threading
import unicodedata

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TextIteratorStreamer
from rapidfuzz import fuzz


# A continuación se encuentra nuestro diccionaro, esta es una clase que recibe
# texto y retorna las entradas del diccionario con mayor correspondencia
# con el input de la busqueda

class LakotaDictionaryTool:
    def __init__(self, raw_data):
        self.entries = self._parse_data(raw_data)

    def _parse_data(self, data):
        entries = []
        for raw_entry in re.split(r"(?=\\lx )", data):
            if not raw_entry.strip():
                continue
            entry_obj = {"lexeme": "", "senses": []}
            current_sense = {"definition": "", "examples": []}
            for line in raw_entry.strip().split("\n"):
                m = re.match(r"^\\(\w+)\s+(.*)", line.strip())
                if not m:
                    continue
                marker, content = m.groups()
                if marker == "lx":
                    entry_obj["lexeme"] = content
                elif marker == "ps":
                    entry_obj["part_of_speech"] = content
                elif marker == "sn":
                    if current_sense["definition"] or current_sense["examples"]:
                        entry_obj["senses"].append(current_sense)
                    current_sense = {"definition": "", "examples": [], "usage": "", "sense_number": content}
                elif marker == "de":
                    current_sense["definition"] = content
                elif marker == "ue":
                    current_sense["usage"] = content
                elif marker == "xv":
                    current_sense["examples"].append({"lakota": content, "english": ""})
                elif marker == "xe" and current_sense["examples"]:
                    current_sense["examples"][-1]["english"] = content
            if current_sense["definition"] or current_sense["examples"]:
                entry_obj["senses"].append(current_sense)
            if entry_obj["lexeme"]:
                entries.append(entry_obj)
        return entries

    def _norm(self, text):
        if not text:
            return ""
        text = text.replace("ŋ", "n").replace("Ŋ", "N")
        text = unicodedata.normalize("NFD", text)
        return "".join(c for c in text if unicodedata.category(c) != "Mn").lower().strip()

    def _fuzzy(self, query, text, nq=None, nt=None):
        if not text:
            return 0.0
        nq = nq or self._norm(query)
        nt = nt or self._norm(text)
        if nq == nt:
            return 1.0
        return max((fuzz.ratio(nq, w) / 100.0 for w in re.findall(r"\w+", nt)), default=0.0)

    def _exact_word(self, q, t):
        return bool(t and q and re.search(r"\b" + re.escape(q) + r"\b", t))

    def search(self, query, limit=5, threshold=0.65):
        results = []
        nq = self._norm(query)
        for entry in self.entries:
            best = 0.0
            lx = entry.get("lexeme", "")
            nlx = self._norm(lx)
            best = max(best, 3.0 if nlx == nq else self._fuzzy(query, lx, nq, nlx) * 1.5)
            for sense in entry["senses"]:
                d = sense.get("definition", "")
                nd = self._norm(d)
                if nd == nq:
                    best = max(best, 2.5)
                elif self._exact_word(nq, nd):
                    best = max(best, 2.1)
                else:
                    penalty = 0.9 if len(nd) > len(nq) * 3 else 1.0
                    best = max(best, self._fuzzy(query, d, nq, nd) * penalty)
                for ex in sense.get("examples", []):
                    for field, exact_s, mult in [("lakota", 2.8, 0.8), ("english", 2.3, 0.8)]:
                        raw = ex.get(field, "")
                        nr = self._norm(raw)
                        if nr == nq:
                            best = max(best, exact_s)
                        elif self._exact_word(nq, nr):
                            best = max(best, exact_s - 0.6)
                        else:
                            best = max(best, self._fuzzy(query, raw, nq, nr) * mult)
            if best >= threshold:
                results.append((best, entry))
        results.sort(key=lambda x: -x[0])
        return [r[1] for r in results[:limit]]

    def format_results(self, results):
        if not results:
            return "No results found."
        lines = []
        for entry in results:
            line = f"**{entry.get('lexeme', '?')}** ({entry.get('part_of_speech', 'pk')})"
            senses = entry.get("senses", [])
            for i, s in enumerate(senses, 1):
                prefix = f" {i}. " if len(senses) > 1 else " "
                line += f"{prefix}{s.get('definition', '').strip()}"
                if s.get("usage", "").strip():
                    line += f" [Note: {s['usage'].strip()}]"
                if s.get("examples"):
                    exs = "; ".join(f"{e['lakota']} -> {e['english']}" for e in s["examples"])
                    line += f" | Example: {exs}"
            lines.append(line)
        return "\n".join(lines)


# Definimos las herramientas existentes,
# el formato a utilizar depende del modelo a usar
TOOLS = [
    {
        "type": "function",
        "function": {
            "name": "search_dictionary",
            "description": "Performs a fuzzy text search on the Lakota dictionary.",
            "parameters": {
                "type": "object",
                "properties": {
                    "query": {"type": "string", "description": "The word or definition to search for."},
                    "limit": {"type": "integer", "description": "Max results (default 4).", "default": 4},
                },
                "required": ["query"],
            },
        },
    }
]

# %%
import json
import re
import threading
import unicodedata

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TextIteratorStreamer
from rapidfuzz import fuzz


# Esta es la instruccion que le entregaremos al modelo,
# es utilizada para variar su comportamiento

SYSTEM_PROMPT_TEMPLATE = """# Tools

You have access to the following functions:

<tools>
{tools_block}
</tools>

<tool_call>
<function=example_function_name>
<parameter=example_parameter_1>
value_1
</parameter>
</function>
</tool_call>

Reminder:
- Function calls MUST follow the specified format: an inner <function=...></function> block must be nested within <tool_call></tool_call> XML tags.
- Required parameters MUST be specified.

You are a careful English-to-Lakota translator.

Rules:
1. For every translation request, use the search_dictionary function at least once before giving the final translation.
2. You may call the dictionary multiple times to verify roots, alternate spellings, affixes, or meanings.
3. Prefer conservative translations grounded in the dictionary results.
4. You have a maximum of {max_turns} turns available, there is no limit to the number of tool calls in total or per turn, but find the necessary words efficiently and provide the final answer before exceeding this limit.
5. In the final answer, output:
   - Lakota: <final translation>
   - Notes: <brief explanation of word choices and uncertainty if any>
6. Do not invent dictionary evidence that was not returned by the tool.
7. You do not have to rely entirely on exact definitions, the tool results can include examples of translations from which you can infer the meaning of the word in the context of the sentence.
8. It is recommended to perform multiple tool calls in parallel.
9. Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls, if you do not have any tool-calling turns left then proceed to answer the translation with the information you currently have.
10. Do not make up any Lakota words of definition on your own, your internal knowledge cannot be trusted and rely entirely on the results of the dictionary tool call.
"""

TOOL_CALL_RE = re.compile(r"<tool_call>\s*<function=([^\n>]+)>\s*(.*?)</function>\s*</tool_call>", re.DOTALL)
PARAM_RE = re.compile(r"<parameter=([^>\n]+)>\s*(.*?)\s*</parameter>", re.DOTALL)


def parse_tool_calls(text):
    calls = []
    for fn_name, fn_body in TOOL_CALL_RE.findall(text or ""):
        args = {}
        for pname, pval in PARAM_RE.findall(fn_body):
            try:
                args[pname.strip()] = json.loads(pval.strip())
            except Exception:
                args[pname.strip()] = pval.strip()
        calls.append({"name": fn_name.strip(), "arguments": args})
    return calls


def execute_tool_call(name, args, dictionary_tool):
    if name != "search_dictionary":
        return f"ERROR: Unknown tool '{name}'."
    query = args.get("query")
    if not isinstance(query, str) or not query.strip():
        return "ERROR: search_dictionary requires a non-empty string 'query'."
    limit = int(args.get("limit", 4))
    return dictionary_tool.format_results(dictionary_tool.search(query=query, limit=limit))


def load_model(model_name="Qwen/Qwen3-4B", lora_path=None, load_in_4bit=False, flash_attn=False):
    tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, padding_side="left")
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    bnb_config = None
    if load_in_4bit:
        bnb_config = BitsAndBytesConfig(
            load_in_4bit=True, bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.bfloat16, bnb_4bit_use_double_quant=True,
        )

    model = AutoModelForCausalLM.from_pretrained(
        model_name, trust_remote_code=True, quantization_config=bnb_config,
        torch_dtype=torch.bfloat16 if not load_in_4bit else None,
        device_map="auto",
        attn_implementation="flash_attention_2" if flash_attn else None,
    )

    if lora_path:
        from peft import PeftModel
        model = PeftModel.from_pretrained(model, lora_path).merge_and_unload()

    model.eval()
    return model, tokenizer

def _build_eos_token_ids(tokenizer):
    eos_token_ids = []
    if tokenizer.eos_token_id is not None:
        eos_token_ids.append(tokenizer.eos_token_id)

    vocab = tokenizer.get_vocab()
    for token in ["<|im_end|>", "<|endoftext|>"]:
        token_id = vocab.get(token)
        if token_id is not None and token_id not in eos_token_ids:
            eos_token_ids.append(token_id)

    return eos_token_ids


def _clean_generated_text(text: str) -> str:
    cutoff_markers = [
        "<tool_response>",
        "user\n<tool_response>",
        "user\n",
    ]
    for marker in cutoff_markers:
        if marker in text:
            text = text.split(marker)[0]
    return text.strip()


def _render_chat(tokenizer, messages, add_generation_prompt: bool) -> str:
    return tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=add_generation_prompt,
        enable_thinking=True,
    )


def _build_incremental_input_ids(tokenizer, cached_messages, current_messages, device):
    full_text = _render_chat(tokenizer, current_messages, add_generation_prompt=True)

    if not cached_messages:
        input_ids = tokenizer(
            full_text,
            add_special_tokens=False,
            return_tensors="pt",
        ).input_ids.to(device)
        return input_ids, False

    cached_text = _render_chat(tokenizer, cached_messages, add_generation_prompt=False)

    if full_text.startswith(cached_text):
        delta_text = full_text[len(cached_text):]
        input_ids = tokenizer(
            delta_text,
            add_special_tokens=False,
            return_tensors="pt",
        ).input_ids.to(device)
        return input_ids, False

    input_ids = tokenizer(
        full_text,
        add_special_tokens=False,
        return_tensors="pt",
    ).input_ids.to(device)
    return input_ids, True


def generate(
    model,
    tokenizer,
    input_ids,
    past_key_values=None, # Parametro importante, cache
    max_new_tokens=2048,
    temperature=0.6,
    stream=False,
):
    eos_token_id = _build_eos_token_ids(tokenizer)

    gen_kwargs = dict(
        input_ids=input_ids,
        past_key_values=past_key_values,
        max_new_tokens=max_new_tokens,
        pad_token_id=tokenizer.pad_token_id,
        eos_token_id=eos_token_id,
        # En general los modelos tienen parametros de muestreo recomendados
        # con los que generan mejores respuestas (mayor puntaje en algun benchmark)
        # https://huggingface.co/Qwen/Qwen3.5-2B#best-practices
        temperature=temperature,
        do_sample=temperature>0,
        top_p=0.95,
        top_k=20,
        min_p=0.0,
        repetition_penalty=1.0,
        return_dict_in_generate=True,
        use_cache=True,
        stop_strings=["<tool_response>", "<|im_start|>", "user\n<tool_response>"],
        tokenizer=tokenizer,
    )

    if stream:
        streamer = TextIteratorStreamer(
            tokenizer,
            skip_prompt=True,
            skip_special_tokens=False,
        )
        gen_kwargs["streamer"] = streamer

        output_container = {}

        def target():
            with torch.no_grad():
                output_container["result"] = model.generate(**gen_kwargs)

        thread = threading.Thread(target=target)
        thread.start()

        for chunk in streamer:
            print(chunk, end="", flush=True)
        print()

        thread.join()
        outputs = output_container["result"]
    else:
        with torch.no_grad():
            outputs = model.generate(**gen_kwargs)

    # Decode only newly generated tokens relative to THIS call's input_ids
    gen_tokens = outputs.sequences[0, input_ids.shape[1]:]
    generated_text = tokenizer.decode(gen_tokens, skip_special_tokens=True)
    generated_text = _clean_generated_text(generated_text)

    new_past_key_values = getattr(outputs, "past_key_values", None)
    return generated_text, new_past_key_values


def translate(
    english_text,
    dictionary_tool,
    model,
    tokenizer,
    max_turns=5,
    max_new_tokens=2048,
    temperature=0.6,
    stream=False,
    output_file=None,
):
    tools_block = "\n".join(json.dumps(t, ensure_ascii=False) for t in TOOLS)
    system_prompt = SYSTEM_PROMPT_TEMPLATE.format(
        tools_block=tools_block,
        max_turns=max_turns,
    )

    messages = [
        {"role": "system", "content": system_prompt},
        {
            "role": "user",
            "content": f"Translate the following English text into Lakota.\n\nEnglish: {english_text}",
        },
    ]

    # Messages already represented by the current KV cache.
    cached_messages = []
    past_key_values = None
    assistant_text = ""

    for step in range(max_turns + 2):
        print(f"\n--- Turn {step + 1} ---")

        current_input_ids, reset_cache = _build_incremental_input_ids(
            tokenizer=tokenizer,
            cached_messages=cached_messages,
            current_messages=messages,
            device=model.device,
        )

        if reset_cache:
            past_key_values = None

        assistant_text, past_key_values = generate(
            model=model,
            tokenizer=tokenizer,
            input_ids=current_input_ids,
            past_key_values=past_key_values,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            stream=stream,
        )

        if not stream:
            print(f"Assistant:\n{assistant_text}")

        messages.append({"role": "assistant", "content": assistant_text})

        # Cache now represents everything up through this assistant turn.
        cached_messages = list(messages)

        tool_calls = parse_tool_calls(assistant_text)

        if not tool_calls:
            print("\nDone (no tool calls).")
            break

        if step >= max_turns:
            print("\nMax turns exhausted. The model will not be allowed further tool calls.")
            reminder = (
                "You have 0 turns left for dictionary searches."
                "You MUST provide the final Lakota translation now in your next response."
            )
            messages.append({"role": "user", "content": reminder})
            continue

        tool_response_blocks = []
        for tc in tool_calls:
            print(f"  Tool: {tc['name']}({tc['arguments']})")
            output = execute_tool_call(tc["name"], tc["arguments"], dictionary_tool)
            print(f"  Result: {output}")
            tool_response_blocks.append(f"<tool_response>\n{output}\n</tool_response>")

        steps_left = max_turns - step - 1
        if steps_left > 0:
            reminder = (
                f"\n\n<system_reminder>You have {steps_left} turn(s) left. "
                "Please provide the final translation if you have enough information."
                "</system_reminder>"
            )
        else:
            reminder = (
                "\n\n<system_reminder>You have 0 turns left for dictionary searches. "
                "You MUST provide the final Lakota translation now in your next response "
                "without using any more tools.</system_reminder>"
            )

        tool_content = "\n".join(tool_response_blocks) + reminder
        messages.append({"role": "user", "content": tool_content})

    if output_file:
        with open(output_file, "w", encoding="utf-8") as f:
            for msg in messages:
                f.write(json.dumps(msg, ensure_ascii=False) + "\n")
        print(f"Saved to {output_file}")

    return assistant_text.strip(), messages

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import torch

# La architectura de modelos Qwen de Alibaba es muy utilizada,
# tiene uno de los mejores desempenos en relacion a su tamano
# y tiene gran variedad en tamanos de modelos, utiles en distintas
# capacidades de hardware, los mas pequenos son de 0.8, 2 y 4 billones de
# parametros
base_model_id = "Qwen/Qwen3.5-4B"

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=torch.float16,
    device_map="cuda"
)
tokenizer = AutoTokenizer.from_pretrained(base_model_id)
# Out:
# config.json:   0%|          | 0.00/3.16k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/76.2k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/426 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/16.7k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/6.72M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/3.35M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/12.8M [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/7.76k [00:00<?, ?B/s]

# %%
raw_data = open("dict_A_to_I.txt", "r", encoding="utf-8").read()
dictionary_tool = LakotaDictionaryTool(raw_data)

# %%
translate("The quick brown fox jumps over the lazy dog", dictionary_tool, base_model, tokenizer, stream=True, max_turns=2)
# Out:
# --- Turn 1 ---
# Thinking Process:
#
# 1.  **Analyze the Request:**
#     *   Task: Translate the English sentence "The quick brown fox jumps over the lazy dog" into Lakota.
#     *   Constraint 1: Use the `search_dictionary` function at least once before giving the final translation.
#     *   Constraint 2: Call the dictionary multiple times if necessary to verify roots, alternate spellings, etc.
#     *   Constraint 3: Prefer conservative translations grounded in dictionary results.
#     *   Constraint 4: Output format must include "Lakota: <translation>" and "Notes: <brief explanation...>".
#     *   Constraint 5: Do not invent dictionary evidence.
#     *   Constraint 6: Start each turn by stating the number of tool calls allowed (though the prompt implies I should just do the work, the instruction says "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls". This is a bit ambiguous in a single-turn context, but I should follow the spirit of checking limits). Actually, looking at the system prompt "You have a maximum of 2 turns available", I need to manage my tool calls carefully. However, usually, I can make multiple tool calls in one turn. Let's start with 1 tool call to check relevant words.
#     *   Constraint 7: Start every turn by repeating the number of turns allowed for tool calls. Wait, the instruction says "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls". This seems to be a specific protocol for this interface. I should state "I have 2 turns available" or similar if I'm planning ahead, but usually, this means I should acknowledge the turn limit. Let's assume I can make multiple tool calls in this turn.
#     *   Constraint 8: Find the translation efficiently.
#
# 2.  **Identify Key Words:**
#     *   The (article - often omitted or handled differently in Lakota)
#     *   quick (adjective)
#     *   brown (adjective)
#     *   fox (noun)
#     *   jumps (verb)
#     *   over (preposition)
#     *   the (article)
#     *   lazy (adjective)
#     *   dog (noun)
#
# 3.  **Initial Dictionary Search Strategy:**
#     *   I need to search for: "fox", "dog", "jump", "quick", "brown", "lazy".
#     *   Since I can make multiple tool calls, I should search for the most critical nouns and verbs first.
#     *   Let's search for "fox" and "dog" first as they are specific nouns.
#     *   Let's search for "jump" or "run" (jumps).
#     *   Let's search for "quick" and "slow" (lazy might be different).
#
# 4.  **Execute Tool Calls (Turn 1):**
#     *   I will search for "fox" and "dog" and "jump" in parallel to save turns.
#     *   Actually, I need to check the specific instructions: "You have a maximum of 2 turns available". This usually means 2 *user* turns or 2 *response* turns? Usually, it means I can make tool calls in one turn, then write the response. But I should be careful.
#     *   Let's start with searching for the core nouns and verbs.
#     *   Query 1: "fox"
#     *   Query 2: "dog"
#     *   Query 3: "jump" or "run"
#     *   Query 4: "quick"
#
#     Wait, I need to check the "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls" instruction.
#     If I am in Turn 1, I should say "I have 2 turns available".
#     Let's start searching.
#
#     *Search 1:* "fox"
#     *Search 2:* "dog"
#     *Search 3:* "jump"
#
#     Let's refine the search queries to be more specific to the Lakota dictionary format (often searching for the root).
#
#     Let's try searching "fox", "dog", "jump".
#
#     Wait, I need to be careful about the "2 turns" limit. If I make 3 tool calls, does that count as 1 turn? Yes, usually tool calls are part of a turn. But the constraint says "You have a maximum of 2 turns available". This might mean I can only make 2 tool calls total across the whole interaction? Or 2 turns of interaction?
#     Standard interpretation for these LLM constraints: I can make multiple tool calls in one message, but I should be mindful of the total turns if the system counts tool calls as turns. However, the instruction says "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls". This implies I am in a state where I have N turns left.
#     Let's assume I have 2 tool call opportunities total or 2 interaction turns. To be safe and efficient, I will try to get the necessary words in one go if possible, or use the 2 turns wisely.
#     Actually, looking at the instruction "You have a maximum of 2 turns available, there is no limit to the number of tool calls in total or per turn". This contradicts "maximum of 2 turns".
#     Okay, "You have a maximum of 2 turns available" is the global constraint. "there is no limit to the number of tool calls in total or per turn" suggests I can call tools as much as I want within those turns.
#     So, I can make multiple tool calls in this first turn.
#     I will search for "fox", "dog", "jump", "quick", "brown", "lazy".
#
#     Let's prioritize:
#     1. fox
#     2. dog
#     3. jump
#     4. quick (or fast)
#     5. lazy (or idle)
#     6. brown (color)
#
#     I will make 4 parallel tool calls to cover the bases.
#
#     *Self-Correction on "Start every turn":* I need to explicitly state the turn count at the beginning of my response.
#     "I have 2 turns available."
#
#     Let's proceed with the search.
#
#     Wait, I need to check if "brown" and "quick" are in the dictionary. Often "quick" is "ciga" or similar, "brown" is "mni" or similar.
#     Let's search.
#
#     Wait, I should check the instruction again: "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls".
#     So I will write "I have 2 turns available." at the start.
#
#     Tool Calls:
#     1. Search "fox"
#     2. Search "dog"
#     3. Search "jump"
#     4. Search "quick"
#     5. Search "brown"
#     6. Search "lazy"
#
#     I'll group them.
#
#     Wait, I need to make sure I don't exceed the "2 turns" limit if the system counts tool calls as turns. The prompt says "maximum of 2 turns available... there is no limit to the number of tool calls in total or per turn". This is slightly contradictory. Usually, "turns" means exchanges. I will assume I can make all necessary tool calls in this first exchange.
#
#     Let's search for "fox", "dog", "jump".
#     Then I'll search for "quick", "brown", "lazy".
#     Actually, let's just do "fox", "dog", "jump", "quick", "brown", "lazy" in one batch if the tool allows multiple queries in one call? No, the tool `search_dictionary` takes one `query` string. I have to call it multiple times.
#     Okay, I will make multiple calls.
#
#     Wait, I need to be careful. If I make 6 calls, does it count as 6 turns? The prompt says "no limit to the number of tool calls in total or per turn". So I can make as many calls as I want. The "2 turns available" likely refers to the number of *response* turns I can make before the session ends or context window fills up. So I can do all searches now.
#
#     Let's pick the most likely roots.
#     Fox: `wiya` or `wica`?
#     Dog: `wakan`?
#     Jump: `wíy`?
#     Quick: `ciga`?
#     Brown: `cay`?
#     Lazy: `sápa`?
#
#     I need to verify.
#
#     Let's make the calls.
#
#     Wait, I need to check the instruction again: "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls".
#     Okay, I will start with "I have 2 turns available."
#
#     Let's execute the searches.
#     Query 1: "fox"
#     Query 2: "dog"
#     Query 3: "jump"
#     Query 4: "quick"
#     Query 5: "brown"
#     Query 6: "lazy"
#
#     Wait, I need to check if the tool allows multiple queries in one message. The schema shows `search_dictionary` takes `
#
# Done (no tool calls).
# ('Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Task: Translate the English sentence "The quick brown fox jumps over the lazy dog" into Lakota.\n    *   Constraint 1: Use the `search_dictionary` function at least once before giving the final translation.\n    *   Constraint 2: Call the dictionary multiple times if necessary to verify roots, alternate spellings, etc.\n    *   Constraint 3: Prefer conservative translations grounded in dictionary results.\n    *   Constraint 4: Output format must include "Lakota: <translation>" and "Notes: <brief explanation...>".\n    *   Constraint 5: Do not invent dictionary evidence.\n    *   Constraint 6: Start each turn by stating the number of tool calls allowed (though the prompt implies I should just do the work, the instruction says "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls". This is a bit ambiguous in a single-turn context, but I should follow the spirit of checking limits). Actually, looking at the system prompt "You have a maximum of 2 turns available", I need to manage my tool calls carefully. However, usually, I can make multiple tool calls in one turn. Let\'s start with 1 tool call to check relevant words.\n    *   Constraint 7: Start every turn by repeating the number of turns allowed for tool calls. Wait, the instruction says "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls". This seems to be a specific protocol for this interface. I should state "I have 2 turns available" or similar if I\'m planning ahead, but usually, this means I should acknowledge the turn limit. Let\'s assume I can make multiple tool calls in this turn.\n    *   Constraint 8: Find the translation efficiently.\n\n2.  **Identify Key Words:**\n    *   The (article - often omitted or handled differently in Lakota)\n    *   quick (adjective)\n    *   brown (adjective)\n    *   fox (noun)\n    *   jumps (verb)\n    *   over (preposition)\n    *   the (article)\n    *   lazy (adjective)\n    *   dog (noun)\n\n3.  **Initial Dictionary Search Strategy:**\n    *   I need to search for: "fox", "dog", "jump", "quick", "brown", "lazy".\n    *   Since I can make multiple tool calls, I should search for the most critical nouns and verbs first.\n    *   Let\'s search for "fox" and "dog" first as they are specific nouns.\n    *   Let\'s search for "jump" or "run" (jumps).\n    *   Let\'s search for "quick" and "slow" (lazy might be different).\n\n4.  **Execute Tool Calls (Turn 1):**\n    *   I will search for "fox" and "dog" and "jump" in parallel to save turns.\n    *   Actually, I need to check the specific instructions: "You have a maximum of 2 turns available". This usually means 2 *user* turns or 2 *response* turns? Usually, it means I can make tool calls in one turn, then write the response. But I should be careful.\n    *   Let\'s start with searching for the core nouns and verbs.\n    *   Query 1: "fox"\n    *   Query 2: "dog"\n    *   Query 3: "jump" or "run"\n    *   Query 4: "quick"\n\n    Wait, I need to check the "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls" instruction.\n    If I am in Turn 1, I should say "I have 2 turns available".\n    Let\'s start searching.\n\n    *Search 1:* "fox"\n    *Search 2:* "dog"\n    *Search 3:* "jump"\n\n    Let\'s refine the search queries to be more specific to the Lakota dictionary format (often searching for the root).\n\n    Let\'s try searching "fox", "dog", "jump".\n\n    Wait, I need to be careful about the "2 turns" limit. If I make 3 tool calls, does that count as 1 turn? Yes, usually tool calls are part of a turn. But the constraint says "You have a maximum of 2 turns available". This might mean I can only make 2 tool calls total across the whole interaction? Or 2 turns of interaction?\n    Standard interpretation for these LLM constraints: I can mak ...
#  [{'role': 'system',
#    'content': '# Tools\n\nYou have access to the following functions:\n\n<tools>\n{"type": "function", "function": {"name": "search_dictionary", "description": "Performs a fuzzy text search on the Lakota dictionary.", "parameters": {"type": "object", "properties": {"query": {"type": "string", "description": "The word or definition to search for."}, "limit": {"type": "integer", "description": "Max results (default 4).", "default": 4}}, "required": ["query"]}}}\n</tools>\n\n<tool_call>\n<function=example_function_name>\n<parameter=example_parameter_1>\nvalue_1\n</parameter>\n</function>\n</tool_call>\n\nReminder:\n- Function calls MUST follow the specified format: an inner <function=...></function> block must be nested within <tool_call></tool_call> XML tags.\n- Required parameters MUST be specified.\n\nYou are a careful English-to-Lakota translator.\n\nRules:\n1. For every translation request, use the search_dictionary function at least once before giving the final translation.\n2. You may call the dictionary multiple times to verify roots, alternate spellings, affixes, or meanings.\n3. Prefer conservative translations grounded in the dictionary results.\n4. You have a maximum of 2 turns available, there is no limit to the number of tool calls in total or per turn, but find the necessary words efficiently and provide the final answer before exceeding this limit.\n5. In the final answer, output:\n   - Lakota: <final translation>\n   - Notes: <brief explanation of word choices and uncertainty if any>\n6. Do not invent dictionary evidence that was not returned by the tool.\n7. You do not have to rely entirely on exact definitions, the tool results can include examples of translations from which you can infer the meaning of the word in the context of the sentence.\n8. It is recommended to perform multiple tool calls in parallel.\n9. Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls, if you do not have any tool-calling turns left then proceed to answer the translation with the information you currently have.\n10. Do not make up any Lakota words of definition on your own, your internal knowledge cannot be trusted and rely entirely on the results of the dictionary tool call.\n'},
#   {'role': 'user',
#    'content': 'Translate the following English text into Lakota.\n\nEnglish: The quick brown fox jumps over the lazy dog'},
#   {'role': 'assistant',
#    'content': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Task: Translate the English sentence "The quick brown fox jumps over the lazy dog" into Lakota.\n    *   Constraint 1: Use the `search_dictionary` function at least once before giving the final translation.\n    *   Constraint 2: Call the dictionary multiple times if necessary to verify roots, alternate spellings, etc.\n    *   Constraint 3: Prefer conservative translations grounded in dictionary results.\n    *   Constraint 4: Output format must include "Lakota: <translation>" and "Notes: <brief explanation...>".\n    *   Constraint 5: Do not invent dictionary evidence.\n    *   Constraint 6: Start each turn by stating the number of tool calls allowed (though the prompt implies I should just do the work, the instruction says "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls". This is a bit ambiguous in a single-turn context, but I should follow the spirit of checking limits). Actually, looking at the system prompt "You have a maximum of 2 turns available", I need to manage my tool calls carefully. However, usually, I can make multiple tool calls in one turn. Let\'s start with 1 tool call to check relevant words.\n    *   Constraint 7: Start every turn by repeating the number of turns allowed for tool calls. Wait, the instruction says "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls". This seems to be a specific protocol for this interface. I should state "I have 2 turns available" or similar if I\'m planning ahead, but usually, this means I should acknowledge the turn limit. Let\'s assume I can make multiple tool calls in this turn.\n    *   Constraint 8: Find the translation efficiently.\n\n2.  **Identify Key Words:**\n    *   The (article - often omitted or handled differently in Lakota)\n    *   quick (adjective)\n    *   brown (adjective)\n    *   fox (noun)\n    *   jumps (verb)\n    *   over (preposition)\n    *   the (article)\n    *   lazy (adjective)\n    *   dog (noun)\n\n3.  **Initial Dictionary Search Strategy:**\n    *   I need to search for: "fox", "dog", "jump", "quick", "brown", "lazy".\n    *   Since I can make multiple tool calls, I should search for the most critical nouns and verbs first.\n    *   Let\'s search for "fox" and "dog" first as they are specific nouns.\n    *   Let\'s search for "jump" or "run" (jumps).\n    *   Let\'s search for "quick" and "slow" (lazy might be different).\n\n4.  **Execute Tool Calls (Turn 1):**\n    *   I will search for "fox" and "dog" and "jump" in parallel to save turns.\n    *   Actually, I need to check the specific instructions: "You have a maximum of 2 turns available". This usually means 2 *user* turns or 2 *response* turns? Usually, it means I can make tool calls in one turn, then write the response. But I should be careful.\n    *   Let\'s start with searching for the core nouns and verbs.\n    *   Query 1: "fox"\n    *   Query 2: "dog"\n    *   Query 3: "jump" or "run"\n    *   Query 4: "quick"\n\n    Wait, I need to check the "Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls" instruction.\n    If I am in Turn 1, I should say "I have 2 turns available".\n    Let\'s start searching.\n\n    *Search 1:* "fox"\n    *Search 2:* "dog"\n    *Search 3:* "jump"\n\n    Let\'s refine the search queries to be more specific to the Lakota dictionary format (often searching for the root).\n\n    Let\'s try searching "fox", "dog", "jump".\n\n    Wait, I need to be careful about the "2 turns" limit. If I make 3 tool calls, does that count as 1 turn? Yes, usually tool calls are part of a turn. But the constraint says "You have a maximum of 2 turns available". This might mean I can only make 2 tool calls total across the whole interaction? Or 2 turns of interaction?\n    Standard interpretation for these LLM constrain ...

# %% [markdown]
# # Parameter Efficient Fine-Tuning (PEFT)
#
# El tipo de PEFT que vamos a utilizar se llama Low-Rank Adaptation (LoRA). Este método añade 2 matrices de menor tamaño como parámetros entrenables que funcionan como adaptadores, usualmente sobre cada uno de los pesos original del modelo pero podría ser sobre solo los pesos de la atención por ejemplo. Algunas de las ventajas que LoRA puede presentar es menor interferencia (_catastrophic forgetting_) sobre la información en los pesos y menor uso de memoria.
#
# El menor uso de memoria es debido a que no necesitamos almacenar todos los pesos en _float32_ (4 bytes), solo las nuevas matrices de adaptación, y los parámetros actuales del modelo pueden ser almacenados con 2 bytes (_float16_ o _bfloat16_).
#
# Además, ya que solo entrenamos estas nuevas matrices, el optimizador matiene estados solamente para estos pesos (por ejemplo _Adam_ mantiene información sobre la varianza y momentum para cada peso, y como usualmente también son almacenados en _float32_, representan 8 bytes adicionales por cada peso entrenable).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import argparse
import json
import os
import re
from pathlib import Path
from typing import Dict, List

import torch
from datasets import Dataset
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
)
from trl import SFTTrainer


def load_conversations(conversation_dirs: List[str]) -> List[List[Dict]]:
    """Load all .jsonl conversation files, each as a list of messages."""
    conversations = []
    for d in conversation_dirs:
        p = Path(d)
        if not p.exists():
            print(f"Warning: {d} does not exist, skipping.")
            continue
        for f in sorted(p.glob("*.jsonl")):
            if "FAILED" in f.name:
                continue
            msgs = []
            with open(f, encoding="utf-8") as fh:
                for line in fh:
                    line = line.strip()
                    if line:
                        msgs.append(json.loads(line))
            if msgs:
                conversations.append(msgs)
    return conversations


def format_conversation_for_training(
    messages: List[Dict],
    include_reasoning: bool = True,
) -> List[Dict[str, str]]:
    formatted: List[Dict[str, str]] = []

    for msg in messages:
        role = msg["role"]
        content = msg.get("content", "") or ""
        reasoning = msg.get("reasoning", "") or ""

        if role == "system":
            clean = re.sub(
                r"You have a maximum of \d+ turns.*?this limit\.",
                "Use the dictionary tool as many times as needed to produce an accurate translation.",
                content,
                flags=re.DOTALL,
            )
            formatted.append({"role": "system", "content": clean})

        elif role == "user":
            formatted.append({"role": "user", "content": content})

        elif role == "assistant":
            if include_reasoning and reasoning.strip():
                combined = f"<think>\n{reasoning.strip()}\n</think>\n{content}"
            else:
                combined = content
            formatted.append({"role": "assistant", "content": combined})

    return formatted

def build_dataset(
    conversation_dirs: List[str],
    tokenizer,
    include_reasoning: bool = True,
    max_seq_length: int = 4096 * 5,
) -> Dataset:
    raw_convos = load_conversations(conversation_dirs)
    print(f"Loaded {len(raw_convos)} conversations")

    records = []
    skipped = 0
    for convo in raw_convos:
        formatted = format_conversation_for_training(convo, include_reasoning)
        text = tokenizer.apply_chat_template(
            formatted, tokenize=False, add_generation_prompt=False
        )
        token_count = len(tokenizer.encode(text, add_special_tokens=False))
        if token_count > max_seq_length:
            skipped += 1
            continue
        records.append({"text": text})

    print(f"Kept {len(records)} samples, skipped {skipped} (over {max_seq_length} tokens)")
    return Dataset.from_list(records)

def train(
    model_name: str,
    conversation_dirs: List[str],
    output_dir: str,
    include_reasoning: bool = True,
    max_seq_length: int = 20480,
    val_split: float = 0.1,
    load_in_4bit: bool = True,
    load_in_8bit: bool = True,
    flash_attn: bool = False,
    lora_r: int = 16,
    lora_alpha: int = 32,
    lora_dropout: float = 0.05,
    epochs: int = 3,
    batch_size: int = 2,
    gradient_accumulation_steps: int = 8,
    lr: float = 2e-5,
    gradient_checkpointing: bool = True
):
    tokenizer = AutoTokenizer.from_pretrained(
        model_name,
        trust_remote_code=True,
        padding_side="right",
    )
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    dataset = build_dataset(
        conversation_dirs,
        tokenizer,
        include_reasoning=include_reasoning,
        max_seq_length=max_seq_length,
    )

    if val_split > 0 and len(dataset) > 10:
        split = dataset.train_test_split(test_size=val_split, seed=42)
        train_dataset = split["train"]
        eval_dataset = split["test"]
    else:
        train_dataset = dataset
        eval_dataset = None

    bnb_config = None
    if load_in_4bit:
        bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.bfloat16,
            bnb_4bit_use_double_quant=True,
        )

    if load_in_8bit:
        bnb_config = BitsAndBytesConfig(
            load_in_8bit=True,
        )

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        quantization_config=bnb_config,
        torch_dtype=torch.bfloat16 if not load_in_4bit else None,
        device_map="auto",
        attn_implementation="sdpa" if flash_attn else None,
    )

    if load_in_4bit or load_in_8bit:
        model = prepare_model_for_kbit_training(model)

    lora_config = LoraConfig(
        r=lora_r,
        lora_alpha=lora_alpha,
        lora_dropout=lora_dropout,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules="all-linear",
    )
    model = get_peft_model(model, lora_config)
    model.print_trainable_parameters()

    training_args = TrainingArguments(
        output_dir=output_dir,
        num_train_epochs=epochs,
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=1,
        gradient_accumulation_steps=gradient_accumulation_steps,
        learning_rate=lr,
        lr_scheduler_type="cosine",
        warmup_ratio=0.1,
        weight_decay=0.01,
        bf16=True,
        logging_steps=5,
        save_strategy="epoch",
        eval_strategy="steps" if eval_dataset else "no",
        eval_steps=10,
        save_total_limit=5,
        report_to="none",
        gradient_checkpointing=gradient_checkpointing,
        gradient_checkpointing_kwargs={"use_reentrant": False} if gradient_checkpointing else None,
        optim="adamw_torch_fused" if torch.cuda.is_available() else "adamw_torch",
        max_grad_norm=1.0,
        seed=42,
        use_liger_kernel=True,
    )

    trainer = SFTTrainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        processing_class=tokenizer,
    )

    train_output = trainer.train()
    trainer.save_model(os.path.join(output_dir, "final"))
    tokenizer.save_pretrained(os.path.join(output_dir, "final"))
    print(f"\nModel saved to {output_dir}/final")

    return trainer, train_output

# %%
trainer, model_output = train(
    model_name="Qwen/Qwen3.5-2B",
    conversation_dirs=[
        "./conversations_qw_3_6p_2",
    ],
    output_dir="output",
    include_reasoning=True,
    load_in_4bit=False,
    load_in_8bit=False,
    flash_attn=True,
    lora_r=128,
    gradient_checkpointing=False,
    batch_size=1,
    gradient_accumulation_steps=16,
    epochs=1,
)
# Out:
# Loaded 580 conversations
# Kept 580 samples, skipped 0 (over 20480 tokens)
# Loading weights:   0%|          | 0/320 [00:00<?, ?it/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# trainable params: 134,553,600 || all params: 2,016,378,688 || trainable%: 6.6730
# Adding EOS to train dataset:   0%|          | 0/522 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/522 [00:00<?, ? examples/s]
# Building labels for train dataset:   0%|          | 0/522 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/58 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/58 [00:00<?, ? examples/s]
# Building labels for eval dataset:   0%|          | 0/58 [00:00<?, ? examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248044}.
#     <div>
#
#       <progress value='33' max='33' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [33/33 15:51, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Num Tokens</th>
#       <th>Mean Token Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.582291</td>
#       <td>2.359150</td>
#       <td>163840.000000</td>
#       <td>0.575522</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.059131</td>
#       <td>2.032164</td>
#       <td>327530.000000</td>
#       <td>0.612263</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.937570</td>
#       <td>1.953763</td>
#       <td>491370.000000</td>
#       <td>0.620032</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.937570</td>
#       <td>1.950886</td>
#       <td>534378.000000</td>
#       <td>0.619190</td>
#     </tr>
#   </tbody>
# </table><p>
# Model saved to output/final

# %%
translate("The quick brown fox jumps over the lazy dog", dictionary_tool, trainer.model, tokenizer, stream=True, max_turns=2)
# Out:
# --- Turn 1 ---
# The user wants me to translate "The quick brown fox jumps over the lazy dog" into Lakota. I need to search the dictionary for this phrase to find appropriate Lakota equivalents.
#
# Let me search for key words in the phrase:
# 1. "fox" - to find how to say fox in Lakota
# 2. "jump" - to find how to say jump in Lakota
# 3. "lazy" - to find how to say lazy in Lakota
# 4. "dog" - to find how to say dog in Lakota
#
# I'll search for these words to get accurate translations.
# </think>
#
# <tool_call>
# <function=search_dictionary>
# <parameter=query>
# fox
# </parameter>
# <parameter=limit>
# 3
# </parameter>
# </function>
# </tool_call>
# <tool_call>
# <function=search_dictionary>
# <parameter=query>
# lazy
# </parameter>
# <parameter=limit>
# 3
# </parameter>
# </function>
# </tool_call>
# <tool_call>
# <function=search_dictionary>
# <parameter=query>
# jump
# </parameter>
# <parameter=limit>
# 3
# </parameter>
# </function>
# </tool_call>
# <tool_call>
# <function=search_dictionary>
# <parameter=query>
# dog
# </parameter>
# <parameter=limit>
# 3
# </parameter>
# </function>
# </tool_call><|im_end|>
#   Tool: search_dictionary({'query': 'fox', 'limit': 3})
#   Result: **Pešlékhe** (nprop) the Fox Indians
# **šuŋǧíla** (n) red fox
# **tȟokȟála** (n) 1. kit fox (Vulpes macrotis, grayish species) and perhaps gray fox (Urocyon cinereoargenteus) 2. Kit Fox Society (a warrior society)
#   Tool: search_dictionary({'query': 'lazy', 'limit': 3})
#   Result: **hokšíla-wičháȟča** (n) a lazy young fellow (as if he were an old man)
# **imáǧažuyA** (av:2 (caus)) to cause it to rain by means of smth (as by rain-calling ceremony; it is also jokingly said that a lazy person makes it rain when he/she suddenly begins to work hard)
# **kapíŋ** (vaux) to be reluctant to do; not feeling like doing, tired or unwilling to do, disinclined to do; too lazy to do, loath to do, dread doing [Note: always follows verbs, triggers e-ablaut and contraction of the preceding verb] | Example: Okíyag-wakápiŋ. -> I was reluctant to tell him about it.; Waékiye-wakápiŋ. -> I am reluctant to advise him.; Wóčhičiyakapi-wakápiŋ. -> I was reluctant to tell you.; Naǧíyečhiye-wakápiŋ. -> I hate to bother you.; Nuŋwé-wakápiŋ. -> I don't feel like swimming.; Okíčhize kiŋ ektá ye-wákapiŋ. -> I dreaded to go to war.; Okȟópȟe-égna kúpi čhaŋkhé čhethí-kapíŋpi. -> They were going back home through enemy territory, so they dreaded to make fire.; Apȟé-kapíŋ. -> He was tired of waiting for him.; Iyúŋȟ-yakápiŋ he? -> Are you reluctant to ask him about it?; Tuwáš ečhúŋ-kapíŋ šni ká! -> Who wouldn't tire of doing it?; Čhokȟá khí-wakápiŋ. -> I dread to go back unsuccessful.; škaŋkápiŋ -> to be reluctant to move about.
#   Tool: search_dictionary({'query': 'jump', 'limit': 3})
#   Result: **aglíyopsičA** (av:1 (coll)) they all jump down/off
# **áǧa iȟpáyA** (av:1) to fall or jump into water with a splash, to fall sprawling (in diving)
# **áǧiȟpayA** (av:1) to fall or jump into water with a splash, to fall sprawling (in diving)
#   Tool: search_dictionary({'query': 'dog', 'limit': 3})
#   Result: **šúŋka** (n) 1. dog | Example: Šúŋka–tȟáwa kiŋ kičhí yé. -> His dog went with him.; Šúŋka kiŋ našlóg iyáye. -> The dog started off.; Šúŋka kiŋ wapȟápȟapi na hópi. -> The dogs were barking and howling. 2. horse [Note: contracted form |fv{šuŋg} or |fv{šuŋk} is used in compounds for horse vocabulary; also compare |fv{šúŋka} |fv{tȟáwa} 'his dog' with |fv{tȟašúŋke} 'his horse']
# **aȟló** (av:2) to growl over or about a thing (as a dog does over a bone)
# **ayáptaŋyAŋ** (av:2) 1. to overturn smth on sb/smth with one's mouth (as a dog) 2. to make smth happen by predicting it, to bring smth to pass by talking | Example: Núŋȟpaŋpi čháŋ, hé tuwá íčhimani-hí ktiŋ naíŋš iyé táku naȟ’úŋpi kta úŋ hewíčhačheča kéyapi, na tuktéktel ayáptaŋyaŋpi. -> When anyone has a ringing sound in the ear, it means, they say, that some visitor is arriving shortly, or that some news is about to be heard, and occasionally this comes true by their very saying it.; Ayáptaŋyiŋ kte šáŋ. -> If she isn't careful, she will bring it to pass by talking (as they say when anyone says smth that is portentous).; Tuktéktel iyéčheȟčiŋ abláptaŋye s’e. -> Sometimes, I made it happen subsequently by thinking of it.
#
# --- Turn 2 ---
# The user wants me to translate "The quick brown fox jumps over the lazy dog" into Lakota.
#
# From my searches, I found:
# - fox: šúŋǧíla (red fox) or šúŋka (dog)
# - lazy: hokšíla-wičháȟča (lazy young fellow) or kapíŋ (reluctant to do, too lazy to do)
# - jump: aglíyopsičA (they all jump down/off) or áǧa iȟpáyA (fall or jump into water with a splash)
#
# Let me search for more specific translations:
# - "jump over" - I need to find this specific phrase
# - "lazy dog" - I need to find this specific phrase
#
# Let me search for these specific terms.
# </think>
#
# <tool_call>
# <function=search_dictionary>
# <parameter=query>
# jump over
# </parameter>
# <parameter=limit>
# 3
# </parameter>
# </function>
# </tool_call>
# <tool_call>
# <function=search_dictionary>
# <parameter=query>
# lazy dog
# </parameter>
# <parameter=limit>
# 3
# </parameter>
# </function>
# </tool_call>
# <tool_call>
# <function=search_dictionary>
# <parameter=query>
# quick
# </parameter>
# <parameter=limit>
# 3
# </parameter>
# </function>
# </tool_call><|im_end|>
#   Tool: search_dictionary({'query': 'jump over', 'limit': 3})
#   Result: **apsíčA** (av:2) to jump or leap over smth, jump on smth; skip over (also figuratively: ignore, deny) | Example: Wakpála kiŋ uŋkápsičapi. -> We jumped over the creek.; Ikázopi kiŋ apsíča yo. -> Jump over the line.; Čhúŋkaške kiŋ apsíl iyáye. -> He jumped over the fence.; Wawíčhakičuŋzapi kiŋ túŋweni apsíl-wačhíŋpi šni. -> They never attempted to skip the fate decreed to them.; Tókheni oíye apsíl-phičašniyaŋ úŋ čhaŋkhé anáǧoptaŋpi. -> It was impossible to overstep his words (commands) so they obeyed him.; Wičháša kiŋ awíčhapsipsil iyáye. -> He went jumping over the men.
# **mapȟóǧe** (1s.pos)
# **šupé** (n) intestine, gut, entrails | Example: mašúpe -> my intestines; Šúŋka-šupé naíŋš phí kiŋ čheúŋpapi na yútapi. -> The dog's intestines and the liver were roasted and eaten.; Šupé mayúowotȟaŋ. -> I had diarrhea.
#   Tool: search_dictionary({'query': 'lazy dog', 'limit': 3})
#   Result: **glažó** (av:2 (pos)) to blow on one's own instrument (as a flute)
# **yazóg** (cont-av:1)
# **iglázo** (av:2 (refl)) 1. to draw a line on oneself | Example: Tȟaŋsíŋl átaya sab’íč’iyiŋ na wáŋčakiyela ská úŋ iglázo. -> He painted himself black all over and drew one white line on himself. 2. to draw a mark on smth for oneself, mark for oneself (as one's possession), mark as one's own | Example: Hé íčhiyopteya iglázo. -> He marked it as his own with a cross.
#   Tool: search_dictionary({'query': 'quick', 'limit': 3})
#   Result: **kȟo** (root) quick
# **áhuŋhuŋhuŋ** (interj) (very quick) reflex to a very sudden pain, also crying syllables used by (old) men
# **ȟpečášni** (sv:1) to have a lot of stamina, be full of energy or vigor; be assertive, bold, forward; full of life, alert, quick, witty, energetic, lively, taking initiative, peppy, tireless
#
# --- Turn 3 ---
# I need to translate "The quick brown fox jumps over the lazy dog" into Lakota. Let me search for the key words again since I have limited turns left:
#
# 1. Quick - kȟo (root)
# 2. Fox - šúŋǧíla (n) red fox
# 3. Jumps - aglíyopsičA (av:1 (coll)) they all jump down/off (this is for plural, but for singular I need to find the singular form)
# 4. Over - apsíčA (av:2) to jump or leap over smth
# 5. The - šúŋka (n) 1. dog
# 6. Lazy - hokšíla-wičháȟča (n) a lazy young fellow
# 7. Dog - šúŋka (n) dog
#
# Let me search for more specific terms for "jump over" and "lazy" to make sure I have the right words.
# </think>
#
# <tool_call>
# <function=search_dictionary>
# <parameter=limit>
# 3
# </parameter>
# <parameter=query>
# jump over
# </parameter>
# </function>
# </tool_call>
# <tool_call>
# <function=search_dictionary>
# <parameter=limit>
# 3
# </parameter>
# <parameter=query>
# lazy
# </parameter>
# </function>
# </tool_call>
# <tool_call>
# <function=search_dictionary>
# <parameter=limit>
# 3
# </parameter>
# <parameter=query>
# dog
# </parameter>
# </function>
# </tool_call><|im_end|>
#
# Max turns exhausted. The model will not be allowed further tool calls.
#
# --- Turn 4 ---
# I need to translate "The quick brown fox jumps over the lazy dog" into Lakota.
#
# From the dictionary results:
# - fox: šúŋǧíla (red fox)
# - lazy: hokšíla-wičháȟča (lazy young fellow)
# - jump: aglíyopsičA (they all jump down/off)
# - dog: šúŋka (1. dog)
# - quick: kȟo (root)
#
# So the translation would be:
# - The quick brown fox jumps over the lazy dog
# - Lakota: šúŋǧíla kȟo aglíyopsičA šúŋka hokšíla-wičháȟča
# - Notes: This is a play on the famous phrase "The quick brown fox jumps over the lazy dog"
#
# Let me provide the final translation now.
# </think>
#
# **Lakota:** šúŋǧíla kȟo aglíyopsičA šúŋka hokšíla-wičháȟča
#
# **Notes:** This is a playful translation of the famous phrase "The quick brown fox jumps over the lazy dog." The red fox (šúŋǧíla) is used in place of "fox" because it's the most common red fox in Lakota culture. The phrase "jump over" is translated as "aglíyopsičA" (they all jump down/off), which captures the action of jumping over something. "Quick" is translated as "kȟo" (quick). "Lazy" is "hokšíla-wičháȟča" (lazy young fellow).<|im_end|>
#
# Done (no tool calls).
# ('I need to translate "The quick brown fox jumps over the lazy dog" into Lakota.\n\nFrom the dictionary results:\n- fox: šúŋǧíla (red fox)\n- lazy: hokšíla-wičháȟča (lazy young fellow)\n- jump: aglíyopsičA (they all jump down/off)\n- dog: šúŋka (1. dog)\n- quick: kȟo (root)\n\nSo the translation would be:\n- The quick brown fox jumps over the lazy dog\n- Lakota: šúŋǧíla kȟo aglíyopsičA šúŋka hokšíla-wičháȟča\n- Notes: This is a play on the famous phrase "The quick brown fox jumps over the lazy dog"\n\nLet me provide the final translation now.\n</think>\n\n**Lakota:** šúŋǧíla kȟo aglíyopsičA šúŋka hokšíla-wičháȟča\n\n**Notes:** This is a playful translation of the famous phrase "The quick brown fox jumps over the lazy dog." The red fox (šúŋǧíla) is used in place of "fox" because it\'s the most common red fox in Lakota culture. The phrase "jump over" is translated as "aglíyopsičA" (they all jump down/off), which captures the action of jumping over something. "Quick" is translated as "kȟo" (quick). "Lazy" is "hokšíla-wičháȟča" (lazy young fellow).',
#  [{'role': 'system',
#    'content': '# Tools\n\nYou have access to the following functions:\n\n<tools>\n{"type": "function", "function": {"name": "search_dictionary", "description": "Performs a fuzzy text search on the Lakota dictionary.", "parameters": {"type": "object", "properties": {"query": {"type": "string", "description": "The word or definition to search for."}, "limit": {"type": "integer", "description": "Max results (default 4).", "default": 4}}, "required": ["query"]}}}\n</tools>\n\n<tool_call>\n<function=example_function_name>\n<parameter=example_parameter_1>\nvalue_1\n</parameter>\n</function>\n</tool_call>\n\nReminder:\n- Function calls MUST follow the specified format: an inner <function=...></function> block must be nested within <tool_call></tool_call> XML tags.\n- Required parameters MUST be specified.\n\nYou are a careful English-to-Lakota translator.\n\nRules:\n1. For every translation request, use the search_dictionary function at least once before giving the final translation.\n2. You may call the dictionary multiple times to verify roots, alternate spellings, affixes, or meanings.\n3. Prefer conservative translations grounded in the dictionary results.\n4. You have a maximum of 2 turns available, there is no limit to the number of tool calls in total or per turn, but find the necessary words efficiently and provide the final answer before exceeding this limit.\n5. In the final answer, output:\n   - Lakota: <final translation>\n   - Notes: <brief explanation of word choices and uncertainty if any>\n6. Do not invent dictionary evidence that was not returned by the tool.\n7. You do not have to rely entirely on exact definitions, the tool results can include examples of translations from which you can infer the meaning of the word in the context of the sentence.\n8. It is recommended to perform multiple tool calls in parallel.\n9. Start every turn by repeating the number of turns you have in which you are allowed to perform further tool calls, if you do not have any tool-calling turns left then proceed to answer the translation with the information you currently have.\n10. Do not make up any Lakota words of definition on your own, your internal knowledge cannot be trusted and rely entirely on the results of the dictionary tool call.\n'},
#   {'role': 'user',
#    'content': 'Translate the following English text into Lakota.\n\nEnglish: The quick brown fox jumps over the lazy dog'},
#   {'role': 'assistant',
#    'content': 'The user wants me to translate "The quick brown fox jumps over the lazy dog" into Lakota. I need to search the dictionary for this phrase to find appropriate Lakota equivalents.\n\nLet me search for key words in the phrase:\n1. "fox" - to find how to say fox in Lakota\n2. "jump" - to find how to say jump in Lakota\n3. "lazy" - to find how to say lazy in Lakota\n4. "dog" - to find how to say dog in Lakota\n\nI\'ll search for these words to get accurate translations.\n</think>\n\n<tool_call>\n<function=search_dictionary>\n<parameter=query>\nfox\n</parameter>\n<parameter=limit>\n3\n</parameter>\n</function>\n</tool_call>\n<tool_call>\n<function=search_dictionary>\n<parameter=query>\nlazy\n</parameter>\n<parameter=limit>\n3\n</parameter>\n</function>\n</tool_call>\n<tool_call>\n<function=search_dictionary>\n<parameter=query>\njump\n</parameter>\n<parameter=limit>\n3\n</parameter>\n</function>\n</tool_call>\n<tool_call>\n<function=search_dictionary>\n<parameter=query>\ndog\n</parameter>\n<parameter=limit>\n3\n</parameter>\n</function>\n</tool_call>'},
#   {'role': 'user',
#    'content': "<tool_response>\n**Pešlékhe** (nprop) the Fox Indians\n**šuŋǧíla** (n) red fox\n**tȟokȟála** (n) 1. kit fox (Vulpes macrotis, grayish species) and perhaps gray fox (Urocyon cinereoargenteus) 2. Kit Fox Society (a warrior society)\n</tool_response>\n<tool_response>\n**hokšíla-wičháȟča** (n) a lazy young fellow (as if he were an old man)\n**imáǧažuyA** (av:2 (caus)) to cause it to rain by means of smth (as by rain-calling ceremony; it is also jokingly said that a lazy person makes it rain when he/she suddenly begins to work hard)\n**kapíŋ** (vaux) to be reluctant to do; not feeling like doing, tired or unwilling to do, disinclined to do; too lazy to do, loath to do, dread doing [Note: always follows verbs, triggers e-ablaut and contraction of the preceding verb] | Example: Okíyag-wakápiŋ. -> I was reluctant to tell him about it.; Waékiye-wakápiŋ. -> I am reluctant to advise him.; Wóčhičiyakapi-wakápiŋ. -> I was reluctant to tell you.; Naǧíyečhiye-wakápiŋ. -> I hate to bother you.; Nuŋwé-wakápiŋ. -> I don't feel like swimming.; Okíčhize kiŋ ektá ye-wákapiŋ. -> I dreaded to go to war.; Okȟópȟe-égna kúpi čhaŋkhé čhethí-kapíŋpi. -> They were going back home through enemy territory, so they dreaded to make fire.; Apȟé-kapíŋ. -> He was tired of waiting for him.; Iyúŋȟ-yakápiŋ he? -> Are you reluctant to ask him about it?; Tuwáš ečhúŋ-kapíŋ šni ká! -> Who wouldn't tire of doing it?; Čhokȟá khí-wakápiŋ. -> I dread to go back unsuccessful.; škaŋkápiŋ -> to be reluctant to move about.\n</tool_response>\n<tool_response>\n**aglíyopsičA** (av:1 (coll)) they all jump down/off\n**áǧa iȟpáyA** (av:1) to fall or jump into water with a splash, to fall sprawling (in diving)\n**áǧiȟpayA** (av:1) to fall or jump into water with a splash, to fall sprawling (in diving)\n</tool_response>\n<tool_response>\n**šúŋka** (n) 1. dog | Example: Šúŋka–tȟáwa kiŋ kičhí yé. -> His dog went with him.; Šúŋka kiŋ našlóg iyáye. -> The dog started off.; Šúŋka kiŋ wapȟápȟapi na hópi. -> The dogs were barking and howling. 2. horse [Note: contracted form |fv{šuŋg} or |fv{šuŋk} is used in compounds for horse vocabulary; also compare |fv{šúŋka} |fv{tȟáwa} 'his dog' with |fv{tȟašúŋke} 'his horse']\n**aȟló** (av:2) to growl over or about a thing (as a dog does over a bone)\n**ayáptaŋyAŋ** (av:2) 1. to overturn smth on sb/smth with one's mouth (as a dog) 2. to make smth happen by predicting it, to bring smth to pass by talking | Example: Núŋȟpaŋpi čháŋ, hé tuwá íčhimani-hí ktiŋ naíŋš iyé táku naȟ’úŋpi kta úŋ hewíčhačheča kéyapi, na tuktéktel ayáptaŋyaŋpi. -> When anyone has a ringing sound in the ear, it means, they say, that some visitor is arriving shortly, or that some news is about to be heard, and occasionally this comes true by their very saying it.; Ayáptaŋyiŋ kte šáŋ. -> If she isn't careful, she will bring it to pass by talking (as they say when anyone says smth that is portentous).; Tuktéktel iyéčheȟčiŋ abláptaŋye s’e. -> Sometimes, I made it happen subsequently by thinking of it.\n</tool_response>\n\n<system_reminder>You have 1 turn(s) left. Please provide the final translation if you have enough information.</system_reminder>"},
#   {'role': 'assistant',
#    'content': 'The user wants me to translate "The quick brown fox jumps over the lazy dog" into Lakota.\n\nFrom my searches, I found:\n- fox: šúŋǧíla (red fox) or šúŋka (dog)\n- lazy: hokšíla-wičháȟča (lazy young fellow) or kapíŋ (reluctant to do, too lazy to do)\n- jump: aglíyopsičA (they all jump down/off) or áǧa iȟpáyA (fall or jump into water with a splash)\n\nLet me search for more specific translations:\n- "jump over" - I need to find this specific phrase\n- "lazy dog" - I need to find this specific phrase\n\nLet me search for these specific terms.\n</think>\n\n<tool_call>\n<function=search_dictionary>\n<parameter=query>\njump over\n</parameter>\n<parameter=limit>\n3\n</parameter>\n</function>\n</tool_call>\n<tool_call>\n<function=search_dictionary>\n<parameter=query>\nlazy dog\n</parameter>\n<parameter=limit>\n3\n</parameter>\n</function>\n</tool_call>\n<tool_call>\n<function=search_dictionary>\n<parameter=query>\nquick\n</parameter>\n<parameter=limit>\n3\n</parameter>\n</function>\n</tool_call>'},
#   {'role': 'user',
#    'content': "<tool_response>\n**apsíčA** (av:2) to jump or leap over smth, jump on smth; skip over (also figuratively: ignore, deny) | Example: Wakpála kiŋ uŋkápsičapi. -> We jumped over the creek.; Ikázopi kiŋ apsíča yo. -> Jump over the line.; Čhúŋkaške kiŋ apsíl iyáye. -> He jumped over the fence.; Wawíčhakičuŋzapi kiŋ túŋweni apsíl-wačhíŋpi šni. -> They never attempted to skip the fate decreed to them.; Tókheni oíye apsíl-phičašniyaŋ úŋ čhaŋkhé anáǧoptaŋpi. -> It was impossible to overstep his words (commands) so they obeyed him.; Wičháša kiŋ awíčhapsipsil iyáye. -> He went jumping over the men.\n**mapȟóǧe** (1s.pos)\n**šupé** (n) intestine, gut, entrails | Example: mašúpe -> my intestines; Šúŋka-šupé naíŋš phí kiŋ čheúŋpapi na yútapi. -> The dog's intestines and the liver were roasted and eaten.; Šupé mayúowotȟaŋ. -> I had diarrhea.\n</tool_response>\n<tool_response>\n**glažó** (av:2 (pos)) to blow on one's own instrument (as a flute)\n**yazóg** (cont-av:1)\n**iglázo** (av:2 (refl)) 1. to draw a line on oneself | Example: Tȟaŋsíŋl átaya sab’íč’iyiŋ na wáŋčakiyela ská úŋ iglázo. -> He painted himself black all over and drew one white line on himself. 2. to draw a mark on smth for oneself, mark for oneself (as one's possession), mark as one's own | Example: Hé íčhiyopteya iglázo. -> He marked it as his own with a cross.\n</tool_response>\n<tool_response>\n**kȟo** (root) quick\n**áhuŋhuŋhuŋ** (interj) (very quick) reflex to a very sudden pain, also crying syllables used by (old) men\n**ȟpečášni** (sv:1) to have a lot of stamina, be full of energy or vigor; be assertive, bold, forward; full of life, alert, quick, witty, energetic, lively, taking initiative, peppy, tireless\n</tool_response>\n\n<system_reminder>You have 0 turns left for dictionary searches. You MUST provide the final Lakota translation now in your next response without using any more tools.</system_reminder>"},
#   {'role': 'assistant',
#    'content': 'I need to translate "The quick brown fox jumps over the lazy dog" into Lakota. Let me search for the key words again since I have limited turns left:\n\n1. Quick - kȟo (root)\n2. Fox - šúŋǧíla (n) red fox\n3. Jumps - aglíyopsičA (av:1 (coll)) they all jump down/off (this is for plural, but for singular I need to find the singular form)\n4. Over - apsíčA (av:2) to jump or leap over smth\n5. The - šúŋka (n) 1. dog\n6. Lazy - hokšíla-wičháȟča (n) a lazy young fellow\n7. Dog - šúŋka (n) dog\n\nLet me search for more specific terms for "jump over" and "lazy" to make sure I have the right words.\n</think>\n\n<tool_call>\n<function=search_dictionary>\n<parameter=limit>\n3\n</parameter>\n<parameter=query>\njump over\n</parameter>\n</function>\n</tool_call>\n<tool_call>\n<function=search_dictionary>\n<parameter=limit>\n3\n</parameter>\n<parameter=query>\nlazy\n</parameter>\n</function>\n</tool_call>\n<tool_call>\n<function=search_dictionary>\n<parameter=limit>\n3\n</parameter>\n<parameter=query>\ndog\n</parameter>\n</function>\n</tool_call>'},
#   {'role': 'user',
#    'content': 'You have 0 turns left for dictionary searches.You MUST provide the final Lakota translation now in your next response.'},
#   {'role': 'assistant',
#    'content': 'I need to translate "The quick brown fox jumps over the lazy dog" into Lakota.\n\nFrom the dictionary results:\n- fox: šúŋǧíla (red fox)\n- lazy: hokšíla-wičháȟča (lazy young fellow)\n- jump: aglíyopsičA (they all jump down/off)\n- dog: šúŋka (1. dog)\n- quick: kȟo (root)\n\nSo the translation would be:\n- The quick brown fox jumps over the lazy dog\n- Lakota: šúŋǧíla kȟo aglíyopsičA šúŋka hokšíla-wičháȟča\n- Notes: This is a play on the famous phrase "The quick brown fox jumps over the lazy dog"\n\nLet me provide the final translation now.\n</think>\n\n**Lakota:** šúŋǧíla kȟo aglíyopsičA šúŋka hokšíla-wičháȟča\n\n**Notes:** This is a playful translation of the famous phrase "The quick brown fox jumps over the lazy dog." The red fox (šúŋǧíla) is used in place of "fox" because it\'s the most common red fox in Lakota culture. The phrase "jump over" is translated as "aglíyopsičA" (they all jump down/off), which captures the action of jumping over something. "Quick" is translated as "kȟo" (quick). "Lazy" is "hokšíla-wičháȟča" (lazy young fellow).'}])

# %% [markdown]
# # Optimización de Prompt
#
# El comportamiento del modelo depende en gran medida de la instrucción que le entreguemos, con lo que surge la pregunta de como escribir un buen prompt. [GEPA](https://arxiv.org/abs/2507.19457) es un método para optimizar de forma automatizada el prompt. Para hacer esto, utiliza un segundo modelo (uno de mayor capacidad por ejemplo) que propone modificaciones y evalúa su desempeño para construir un prompt de manera evolutiva.
#
# Utilizaremos la librería [DSPy](https://dspy.ai/) que incorpora diversas utilidades para trabajar con LLMs, dentro de ellas una implementatión de GEPA para optimizar prompts. Específicamente veremos [este tutorial](https://dspy.ai/tutorials/gepa_facilitysupportanalyzer/).
#
# **IMPORTANTE**: No es necesario ejecutar las celdas de esta sección. En la clase realizamos una demostración corriendo en un servidor externo ya que necesitamos más capacidad de generación para correr en un tiempo razonable.

# %%
import dspy

# %%
import os
import dspy

lm = dspy.LM(
    "openrouter/mistralai/ministral-3b-2512",
    api_base="https://openrouter.ai/api/v1",
    api_key=os.environ.get("OPENROUTER_API_ KEY", ""),
    model_type="chat"
)

dspy.configure(lm=lm)

# %%
import requests
import dspy
import json
import random

def init_dataset():
    url = "https://raw.githubusercontent.com/meta-llama/llama-prompt-ops/refs/heads/main/use-cases/facility-support-analyzer/dataset.json"
    dataset = json.loads(requests.get(url).text)
    dspy_dataset = [
        dspy.Example({
            "message": d['fields']['input'],
            "answer": d['answer'],
        }).with_inputs("message")
        for d in dataset
    ]
    random.Random(0).shuffle(dspy_dataset)
    train_set = dspy_dataset[:30] # Para optimizar con GEPA usaremos 30 ejemplos de training y 30 de validación
    val_set = dspy_dataset[30:60]
    # Repetiremos cada ejemplo de testing 5 veces para obtener un promedio del resultado final
    test_set = dspy_dataset[int(len(dspy_dataset) * 0.66):] * 5

    return train_set, val_set, test_set


train_set, val_set, test_set = init_dataset()
len(train_set), len(val_set), len(test_set)
# Out:
# (30, 30, 340)

# %%
print("Input Message:")
print(train_set[0]['message'])

print("\n\nGold Answer:")
for k, v in json.loads(train_set[0]['answer']).items():
    print(f"{k}: {v}")
# Out:
# Input Message:
# Subject: Adjusting Bi-Weekly Cleaning Schedule for My Office
#
# Dear ProCare Facility Solutions Support Team,
#
# I hope this message finds you well. My name is Dr. Alex Turner, and I have been utilizing your services for my office space for the past year. I must say, your team's dedication to maintaining a pristine environment has been commendable and greatly appreciated.
#
# I am reaching out to discuss the scheduling of our regular cleaning services. While I find the logistical challenges of coordinating these services intellectually stimulating, I believe we could optimize the current schedule to better suit the needs of my team and our workflow. Specifically, I would like to explore the possibility of adjusting our cleaning schedule to a bi-weekly arrangement, ideally on Tuesdays and Fridays, to ensure our workspace remains consistently clean without disrupting our research activities.
#
# Previously, I have attempted to adjust the schedule through the online portal, but I encountered some difficulties in finalizing the changes. I would appreciate your assistance in making these adjustments or guiding me through the process if there is a more efficient way to do so.
#
# Thank you for your attention to this matter. I look forward to your response and continued excellent service.
#
# Best regards,
#
# Dr. Alex Turner
# Cryptography Researcher
#
#
# Gold Answer:
# categories: {'routine_maintenance_requests': False, 'customer_feedback_and_complaints': False, 'training_and_support_requests': False, 'quality_and_safety_concerns': False, 'sustainability_and_environmental_practices': False, 'cleaning_services_scheduling': True, 'specialized_cleaning_services': False, 'emergency_repair_services': False, 'facility_management_issues': False, 'general_inquiries': False}
# sentiment: neutral
# urgency: low

# %%
from typing import List, Literal


class FacilitySupportAnalyzerUrgency(dspy.Signature):
    """
    Read the provided message and determine the urgency.
    """
    message: str = dspy.InputField()
    urgency: Literal['low', 'medium', 'high'] = dspy.OutputField()

class FacilitySupportAnalyzerSentiment(dspy.Signature):
    """
    Read the provided message and determine the sentiment.
    """
    message: str = dspy.InputField()
    sentiment: Literal['positive', 'neutral', 'negative'] = dspy.OutputField()

class FacilitySupportAnalyzerCategories(dspy.Signature):
    """
    Read the provided message and determine the set of categories applicable to the message.
    """
    message: str = dspy.InputField()
    categories: List[Literal["emergency_repair_services", "routine_maintenance_requests", "quality_and_safety_concerns", "specialized_cleaning_services", "general_inquiries", "sustainability_and_environmental_practices", "training_and_support_requests", "cleaning_services_scheduling", "customer_feedback_and_complaints", "facility_management_issues"]] = dspy.OutputField()

class FacilitySupportAnalyzerMM(dspy.Module):
    def __init__(self):
        self.urgency_module = dspy.ChainOfThought(FacilitySupportAnalyzerUrgency)
        self.sentiment_module = dspy.ChainOfThought(FacilitySupportAnalyzerSentiment)
        self.categories_module = dspy.ChainOfThought(FacilitySupportAnalyzerCategories)

    def forward(self, message: str):
        urgency = self.urgency_module(message=message)
        sentiment = self.sentiment_module(message=message)
        categories = self.categories_module(message=message)

        return dspy.Prediction(
            urgency=urgency.urgency,
            sentiment=sentiment.sentiment,
            categories=categories.categories
        )

program = FacilitySupportAnalyzerMM()

# %%
def score_urgency(gold_urgency, pred_urgency):
    """
    Compute score for the urgency module.
    """
    score = 1.0 if gold_urgency == pred_urgency else 0.0
    return score

def score_sentiment(gold_sentiment, pred_sentiment):
    """
    Compute score for the sentiment module.
    """
    score = 1.0 if gold_sentiment == pred_sentiment else 0.0
    return score

def score_categories(gold_categories, pred_categories):
    """
    Compute score for the categories module.
    Uses the same match/mismatch logic as category accuracy in the score.
    """
    correct = 0
    for k, v in gold_categories.items():
        if v and k in pred_categories:
            correct += 1
        elif not v and k not in pred_categories:
            correct += 1
    score = correct / len(gold_categories)
    return score

def metric(example, pred, trace=None, pred_name=None, pred_trace=None):
    gold = json.loads(example['answer'])

    score_urgency_val = score_urgency(gold['urgency'], pred.urgency)
    score_sentiment_val = score_sentiment(gold['sentiment'], pred.sentiment)
    score_categories_val = score_categories(gold['categories'], pred.categories)

    total = (score_urgency_val + score_sentiment_val + score_categories_val) / 3

    return total

# %%
import dspy
evaluate = dspy.Evaluate(
    devset=test_set,
    metric=metric,
    num_threads=5,
    display_table=True,
    display_progress=True,
    provide_traceback=True,
)

evaluate(program)
# Out:
# Average Metric: 263.50 / 340 (77.5%): 100%|██████████| 340/340 [01:02<00:00,  5.44it/s]
# 2026/07/08 20:37:26 INFO dspy.evaluate.evaluate: Average Metric: 263.5 / 340 (77.5%)
#                                                                    message  \
# 0    Hey ProCare Support Team, Hope you all are doing great! My name is...
# 1    Hey ProCare Team, Hope you’re all doing well! My name’s Jake, and ...
# 2    Subject: Assistance Needed for HVAC Maintenance Hi [Receiver], I h...
# 3    Subject: A Green Inquiry from a Bill Maher Enthusiast Hey ProCare ...
# 4    Subject: Inquiry on Sustainability Practices Dear ProCare Facility...
# ..                                                                     ...
# 335  Subject: Inquiry About Your Eco-Friendly Practices Dear ProCare Fa...
# 336  Subject: Assistance Needed for Facility Management Issue Dear ProC...
# 337  Subject: Request for Training and Support Hi ProCare Support Team,...
# 338  Subject: Concerns About Studio Maintenance and Rent Increase Dear ...
# 339  Subject: Feedback on Recent Maintenance Service Dear ProCare Suppo...
#
#                                                                     answer  \
# 0    {"categories": {"routine_maintenance_requests": false, "customer_f...
# 1    {"categories": {"routine_maintenance_requests": true, "customer_fe...
# 2    {"categories": {"routine_maintenance_requests": true, "customer_fe...
# 3    {"categories": {"routine_maintenance_requests": false, "customer_f...
# 4    {"categories": {"routine_maintenance_requests": false, "customer_f...
# ..                                                                     ...
# 335  {"categories": {"routine_maintenance_requests": false, "customer_f...
# 336  {"categories": {"routine_maintenance_requests": false, "customer_f...
# 337  {"categories": {"routine_maintenance_requests": false, "customer_f...
# 338  {"categories": {"routine_maintenance_requests": true, "customer_fe...
# 339  {"categories": {"routine_maintenance_requests": true, "customer_fe...
#
#     urgency sentiment  \
# 0       low  positive
# 1    medium  positive
# 2    medium   neutral
# 3       low  positive
# 4       low  positive
# ..      ...       ...
# 335     low  positive
# 336  medium  positive
# 337     low  positive
# 338    high  negative
# 339  medium   neutral
#
#                                                            categories  \
# 0                        [sustainability_and_environmental_practices]
# 1         [routine_maintenance_requests, quality_and_safety_concerns]
# 2                                      [routine_maintenance_requests]
# 3     [sustainability_and_environmental_practices, general_inquiries]
# 4                        [sustainability_and_environmental_practices]
# ..                                                                ...
# 335                      [sustainability_and_environmental_practices]
# 336                                      [facility_management_issues]
# 337                                   [training_and_support_requests]
# 338    [facility_management_issues, customer_feedback_and_complaints]
# 339  [routine_maintenance_requests, customer_feedback_and_complaints]
#
#          metric
# 0    ✔️ [1.000]
# 1    ✔️ [0.967]
# 2    ✔️ [1.000]
# 3    ✔️ [0.967]
# 4    ✔️ [0.667]
# ..          ...
# 335  ✔️ [0.600]
# 336  ✔️ [1.000]
# 337  ✔️ [1.000]
# 338  ✔️ [0.267]
# 339  ✔️ [0.967]
#
# [340 rows x 6 columns]
# EvaluationResult(score=77.5, results=<list of 340 results>)

# %%
import json
import dspy

def feedback_urgency(gold_urgency, pred_urgency):
    """
    Generate feedback for the urgency module.
    """
    score = 1.0 if gold_urgency == pred_urgency else 0.0
    if gold_urgency == pred_urgency:
        feedback = f"You correctly classified the urgency of the message as `{gold_urgency}`. This message is indeed of `{gold_urgency}` urgency."
    else:
        feedback = f"You incorrectly classified the urgency of the message as `{pred_urgency}`. The correct urgency is `{gold_urgency}`. Think about how you could have reasoned to get the correct urgency label."
    return feedback, score

def feedback_sentiment(gold_sentiment, pred_sentiment):
    """
    Generate feedback for the sentiment module.
    """
    score = 1.0 if gold_sentiment == pred_sentiment else 0.0
    if gold_sentiment == pred_sentiment:
        feedback = f"You correctly classified the sentiment of the message as `{gold_sentiment}`. This message is indeed `{gold_sentiment}`."
    else:
        feedback = f"You incorrectly classified the sentiment of the message as `{pred_sentiment}`. The correct sentiment is `{gold_sentiment}`. Think about how you could have reasoned to get the correct sentiment label."
    return feedback, score

def feedback_categories(gold_categories, pred_categories):
    """
    Generate feedback for the categories module.
    Uses the same match/mismatch logic as category accuracy in the score.
    """
    correctly_included = [k for k, v in gold_categories.items() if v and k in pred_categories]
    incorrectly_included = [k for k, v in gold_categories.items() if not v and k in pred_categories]
    incorrectly_excluded = [k for k, v in gold_categories.items() if v and k not in pred_categories]
    correctly_excluded = [k for k, v in gold_categories.items() if not v and k not in pred_categories]  # For completeness in accuracy check

    score = (len(correctly_included) + len(correctly_excluded)) / len(gold_categories)

    if score == 1.0:
        fb_text = f"The category classification is perfect. You correctly identified that the message falls under the following categories: `{repr(correctly_included)}`."
    else:
        fb_text = f"The category classification is not perfect. You correctly identified that the message falls under the following categories: `{repr(correctly_included)}`.\n"
        if incorrectly_included:
            fb_text += f"However, you incorrectly identified that the message falls under the following categories: `{repr(incorrectly_included)}`. The message DOES NOT fall under these categories.\n"
        if incorrectly_excluded:
            prefix = "Additionally, " if incorrectly_included else "However, "
            fb_text += f"{prefix}you didn't identify the following categories that the message actually falls under: `{repr(incorrectly_excluded)}`.\n"
        fb_text += "Think about how you could have reasoned to get the correct category labels."
    return fb_text, score

def metric_with_feedback(example, pred, trace=None, pred_name=None, pred_trace=None):
    """
    Computes a score based on agreement between prediction and gold standard for categories, sentiment, and urgency.
    Optionally provides feedback text for a specific predictor module, using the same comparison logic as the score.
    Returns a dspy.Prediction with score (float) and feedback (str).
    """
    # Parse gold standard from example
    gold = json.loads(example['answer'])

    # Compute feedback and scores for all modules
    fb_urgency, score_urgency = feedback_urgency(gold['urgency'], pred.urgency)
    fb_sentiment, score_sentiment = feedback_sentiment(gold['sentiment'], pred.sentiment)
    fb_categories, score_categories = feedback_categories(gold['categories'], pred.categories)

    # Overall score: average of the three accuracies
    total = (score_urgency + score_sentiment + score_categories) / 3

    if pred_name is None:
        return total

    elif pred_name == 'urgency_module.predict':
        feedback = fb_urgency
    elif pred_name == 'sentiment_module.predict':
        feedback = fb_sentiment
    elif pred_name == 'categories_module.predict':
        feedback = fb_categories

    return dspy.Prediction(score=total, feedback=feedback)

# %%
from dspy import GEPA

optimizer = GEPA(
    metric=metric_with_feedback,
    auto="light", ##
    num_threads=50,
    track_stats=True,
    use_merge=False,
    reflection_lm=dspy.LM(model="gemini/gemini-2.5-flash", temperature=0.7, max_tokens=32000, api_key="")
)

# %%
optimized_program = optimizer.compile(
    program,
    trainset=train_set,
    valset=val_set,
)

# %%
for name, pred in optimized_program.named_predictors():
    print("================================")
    print(f"Predictor: {name}")
    print("================================")
    print("Prompt:")
    print(pred.signature.instructions)
    print("*********************************")

# %% [markdown]
# A continuación se encuentra el prompt generado.
#
# ```
# ================================
# Predictor: urgency_module.predict
# ================================
# Prompt:
# Read the provided message and determine its urgency. The urgency levels are 'low', 'medium', and 'high'.
#
# **Instructions for Determining Urgency:**
#
# 1.  **Analyze Keywords and Phrases:**
#     *   **High Urgency Indicators:** Look for explicit terms like "urgent," "immediate," "as soon as possible," "critical," "emergency," "can't wait," "serious concern," "needs immediate action," "safety concern," "health risks."
#     *   **Medium Urgency Indicators:** Look for terms like "persistent issue," "minor leak," "malfunction," "disruption," "scheduled maintenance," "preventative measure," "important to address," "needs attention by [specific, non-immediate date/time]," "impacts efficiency/comfort."
#     *   **Low Urgency Indicators:** Look for terms like "inquiry," "information request," "exploring options," "future planning," "suggestions," "general question," "no immediate issue," "at your earliest convenience" (when not paired with critical issues or existing problems).
#
# 2.  **Assess Potential Impact and Consequences of Delay:**
#     *   **High Urgency:**
#         *   Involves a direct threat to the health, safety, or well-being of individuals (e.g., mold growth with potential health risks, blocked emergency exits, untested fire alarms, structural integrity issues).
#         *   Causes significant operational disruption or complete shutdown of critical services that impact core functions.
#         *   Poses a risk of severe or irreversible damage to property, sensitive equipment, or data.
#         *   Indicates legal or compliance violations that require immediate rectification to avoid penalties or further issues.
#         *   The message explicitly states an immediate need due to critical circumstances.
#     *   **Medium Urgency:**
#         *   Concerns **scheduled or preventative maintenance for critical systems** (e.g., HVAC, plumbing, electrical, IT infrastructure), even if no immediate issues are currently reported. The purpose is to ensure continued functionality, prevent future failures, and maintain a crucial operational environment. **Even if the system is "functioning adequately," routine maintenance for critical infrastructure is essential and not a low priority.**
#         *   Addresses *existing* issues causing minor operational inconvenience or a clear potential for future, more significant problems if not addressed within a reasonable timeframe (e.g., a minor but persistent leak, a non-critical equipment malfunction that doesn't halt operations).
#         *   Represents significant client dissatisfaction, concerns about company policy, ethics, or brand reputation that require a substantial and timely response to maintain trust and credibility.
#         *   Requests services that are important for maintaining operational efficiency, comfort, or a professional environment, but do not pose immediate threats to safety, health, or critical operations.
#         *   Messages indicating a need for action within a specific, but not immediate, timeframe (e.g., "sometime next week," "mid-week appointment") for important, but not critical, tasks.
#     *   **Low Urgency:**
#         *   Comprises purely informational messages or general inquiries that do not require immediate action or address an existing problem.
#         *   Requests for information about services, pricing, training programs, or capabilities where the sender is *exploring options* or *planning for the future*, rather than addressing a current operational need or issue. This includes sales inquiries, requests for proposals, or preliminary information gathering.
#         *   Requests for non-essential services, minor cosmetic improvements, or general suggestions that have no immediate impact on operations, safety, health, or critical functionality.
#         *   Requests with no specific timeline and no significant impact on operations, safety, or health, or where the current situation is completely satisfactory and the request is for a minor enhancement or future consideration.
#
# 3.  **Contextual Interpretation:**
#     *   Always consider the nature of the facility or environment mentioned (e.g., a police precinct, a recording studio, a hospital, a general office building). What might be "low" urgency in one context could be "medium" or "high" in another due to the specific requirements, regulatory environment, or sensitivities of that environment.
#     *   For example, a "routine maintenance request" for an HVAC system in a critical facility (like a precinct, where comfort is "crucial for our team") is classified as `medium` urgency. While it's not an emergency, it's a necessary proactive step to prevent future problems with an essential system and maintain a functional environment. It is not a `low` priority because it directly relates to the upkeep of critical infrastructure.
#
# **General Strategy:**
# When classifying, first determine if there is an *existing problem* or *current operational need* that requires attention. If the message is primarily an *inquiry, exploration of options, or future planning* without an immediate existing issue, it is likely `low` urgency. If there is an existing problem, then assess its severity based on impact and keywords.
#
# **Output Format:**
# Provide your `reasoning` for the urgency classification, followed by the `urgency` label.
# *********************************
# ================================
# Predictor: sentiment_module.predict
# ================================
# Prompt:
# Read the provided message and determine its overall sentiment. Classify the sentiment as one of the following: `positive`, `neutral`, or `negative`.
#
# **Guidance for Sentiment Classification:**
#
# *   **Neutral:** This is the default sentiment for transactional messages, service requests, inquiries, or logistical adjustments. A message should be classified as `neutral` if:
#     *   Its primary purpose is to request a service (e.g., repair, maintenance, scheduling change), ask for information, or make a transactional adjustment.
#     *   It describes an issue or problem (e.g., a severe leak, a malfunctioning HVAC system, difficulty with an online portal), even if the issue is urgent, causes discomfort, or has potential negative consequences (like damage or safety concerns). The *existence of a problem* and its urgency do not automatically make the message's sentiment negative.
#     *   The tone is professional, respectful, and focused on seeking a resolution, adjustment, or information, rather than expressing strong negative emotions, blame, or severe dissatisfaction.
#     *   It includes minor frustrations, feedback about a process (e.g., a delayed response, difficulty using a system), or suggestions for improvement, as long as these are presented professionally and the overarching goal is a service interaction or constructive communication.
#     *   It contains expressions of general appreciation for past services or polite greetings, but the main intent of the message is a new request, adjustment, or problem resolution.
#
# *   **Positive:** A message is `positive` if it expresses genuine satisfaction, praise, gratitude, or commendation. The primary intent of the message must be to convey positive emotion, without being driven by an underlying request for changes, problem resolution, or issues to be addressed.
#
# *   **Negative:** A message is `negative` if it expresses strong dissatisfaction, anger, severe frustration, disappointment, criticism, or blame. This includes overt complaints, grievances, or threats where the primary intent is to convey significant negative emotion or severe disapproval, going beyond a professional request for problem resolution or constructive feedback.
#
# Consider the overall intent and tone of the message. In the context of facility management or customer support, most routine communications involving issues, requests, or adjustments, even if urgent, tend to be `neutral` unless there's a clear and strong emotional deviation indicating severe dissatisfaction or overwhelming praise.
# *********************************
# ================================
# Predictor: categories_module.predict
# ================================
# Prompt:
# You are an expert message classifier for ProCare Facility Solutions. Your task is to analyze incoming customer messages and assign *ALL* relevant categories from a predefined list.
#
# Here's how to approach the task:
#
# 1.  **Understand the Goal:** Identify every single category that accurately describes the content and intent of the message. Do not stop at the most obvious category; you must identify *all* applicable themes.
#
# 2.  **Predefined Categories and Their Meanings:**
#     *   `quality_and_safety_concerns`: This category applies when the sender expresses concerns about the standards, effectiveness, potential harm, or safety aspects of services, products, or the environment maintained by ProCare. This includes issues related to the safety of people, animals (e.g., pets), or sensitive items (e.g., valuable artifacts, delicate surfaces). It can also cover requests for adjustments to protocols to enhance safety or quality.
#     *   `specialized_cleaning_services`: Use this category when the message specifically mentions cleaning products, cleaning methods, or cleaning requirements that are sensitive, unique, or require specific expertise. This includes concerns about residues, potential damage to delicate surfaces (like historical artifacts), or the need for specific types of cleaning solutions (e.g., pet-friendly, non-toxic).
#     *   `sustainability_and_environmental_practices`: This category is for messages related to energy efficiency, environmental impact reduction, eco-friendly products, green certifications, sustainable operations, or concerns about the environmental/health impact of current practices or products (e.g., asking for pet-friendly or non-toxic cleaning options).
#     *   `general_inquiries`: This category applies to broad requests for information, advice, recommendations, case studies, or a deeper understanding of ProCare's services or capabilities. These are often proactive questions, not tied to an immediate problem or specific service request that requires immediate action.
#
# 3.  **Reasoning Process:**
#     *   Read the entire message carefully to grasp its full context, intent, and specific details.
#     *   Identify the main subject and any secondary topics.
#     *   Look for keywords and phrases that directly map to the predefined categories. For example:
#         *   "cleaning products," "delicate surfaces," "artifacts," "pet-friendly," "sensitive items" often point to `specialized_cleaning_services`.
#         *   "environmental impact," "sustainability," "energy efficiency," "green practices," "pet-friendly products" (when the concern is about the environment/health) often point to `sustainability_and_environmental_practices`.
#         *   "inquiry," "seeking advice," "information," "recommendations," "case studies," "deeper understanding" often point to `general_inquiries`.
#         *   "quality," "safety," "concerns," "standards," "protocols," "harm," "preservation" often point to `quality_and_safety_concerns`.
#     *   Consider the sender's motivation: Are they asking for information? Raising a concern? Seeking advice?
#     *   Ensure that for each category you select, you can clearly articulate *why* it applies based on explicit text in the message.
#
# 4.  **Output Format:**
#     *   `reasoning`: Provide a detailed explanation of why each identified category applies, referencing specific parts of the message. If a category was considered but rejected, briefly explain why.
#     *   `categories`: A JSON-formatted list of strings, where each string is an applicable category name from the predefined list. Ensure *all* applicable categories are included.
#
# **Important Considerations:**
# *   A single message can (and often will) fall into multiple categories. Your goal is to identify all of them.
# *   If a message is an "inquiry" about a specific topic (e.g., sustainability), it should *always* be categorized as both `general_inquiries` and the specific topic (e.g., `sustainability_and_environmental_practices`).
# *   Concerns about cleaning products and their effect on sensitive environments (e.g., pets, artifacts) often indicate both `specialized_cleaning_services` and `sustainability_and_environmental_practices` (if related to health/environment) or `quality_and_safety_concerns` (if related to potential harm).
# *********************************
# ```

# %%
import dspy
from typing import List, Literal

class OptimizedFacilitySupportAnalyzerUrgency(dspy.Signature):
    """Read the provided message and determine its urgency. The urgency levels are 'low', 'medium', and 'high'.

**Instructions for Determining Urgency:**

1.  **Analyze Keywords and Phrases:**
    * **High Urgency Indicators:** Look for explicit terms like "urgent," "immediate," "as soon as possible," "critical," "emergency," "can't wait," "serious concern," "needs immediate action," "safety concern," "health risks."
    * **Medium Urgency Indicators:** Look for terms like "persistent issue," "minor leak," "malfunction," "disruption," "scheduled maintenance," "preventative measure," "important to address," "needs attention by [specific, non-immediate date/time]," "impacts efficiency/comfort."
    * **Low Urgency Indicators:** Look for terms like "inquiry," "information request," "exploring options," "future planning," "suggestions," "general question," "no immediate issue," "at your earliest convenience" (when not paired with critical issues or existing problems).

2.  **Assess Potential Impact and Consequences of Delay:**
    * **High Urgency:**
        * Involves a direct threat to the health, safety, or well-being of individuals.
        * Causes significant operational disruption or complete shutdown of critical services.
        * Poses a risk of severe or irreversible damage to property, equipment, or data.
        * Indicates legal or compliance violations requiring immediate rectification.
        * The message explicitly states an immediate need due to critical circumstances.
    * **Medium Urgency:**
        * Concerns **scheduled or preventative maintenance for critical systems** (e.g., HVAC, plumbing, electrical, IT). Even if the system is "functioning adequately," routine maintenance is essential and not a low priority.
        * Addresses *existing* issues causing minor operational inconvenience or potential for future problems.
        * Represents significant client dissatisfaction requiring a substantial response.
        * Requests services important for efficiency or comfort, but not posing immediate threats.
        * Messages indicating a need for action within a specific, but not immediate, timeframe.
    * **Low Urgency:**
        * Comprises purely informational messages or general inquiries.
        * Requests for information where the sender is *exploring options* or *planning for the future*.
        * Requests for non-essential services, minor cosmetic improvements, or general suggestions.
        * Requests with no specific timeline and no significant impact.

3.  **Contextual Interpretation:**
    * Always consider the nature of the facility or environment mentioned. What might be "low" urgency in one context could be "medium" or "high" in another.

**General Strategy:**
When classifying, first determine if there is an *existing problem* or *current operational need*. If the message is primarily an *inquiry, exploration of options, or future planning*, it is likely `low` urgency. If there is an existing problem, then assess its severity.

**Output Format:**
Provide your `reasoning` for the urgency classification, followed by the `urgency` label."""

    message: str = dspy.InputField()
    urgency: Literal['low', 'medium', 'high'] = dspy.OutputField()


class OptimizedFacilitySupportAnalyzerSentiment(dspy.Signature):
    """Read the provided message and determine its overall sentiment. Classify the sentiment as one of the following: `positive`, `neutral`, or `negative`.

**Guidance for Sentiment Classification:**

* **Neutral:** This is the default sentiment for transactional messages, service requests, inquiries, or logistical adjustments. A message should be classified as `neutral` if:
    * Its primary purpose is to request a service, ask for information, or make a transactional adjustment.
    * It describes an issue or problem (even if urgent or uncomfortable). The *existence of a problem* does not automatically make the sentiment negative.
    * The tone is professional, respectful, and focused on seeking a resolution.
    * It includes minor frustrations or feedback presented professionally.
    * It contains general appreciation, but the main intent is a new request.

* **Positive:** A message is `positive` if it expresses genuine satisfaction, praise, gratitude, or commendation. The primary intent must be to convey positive emotion.

* **Negative:** A message is `negative` if it expresses strong dissatisfaction, anger, severe frustration, disappointment, criticism, or blame. This includes overt complaints or threats.

Consider the overall intent and tone of the message. Most routine facility management communications, even if urgent, tend to be `neutral` unless there's a clear emotional deviation."""

    message: str = dspy.InputField()
    sentiment: Literal['positive', 'neutral', 'negative'] = dspy.OutputField()


class OptimizedFacilitySupportAnalyzerCategories(dspy.Signature):
    """You are an expert message classifier for ProCare Facility Solutions. Your task is to analyze incoming customer messages and assign *ALL* relevant categories from a predefined list.

Here's how to approach the task:

1.  **Understand the Goal:** Identify every single category that accurately describes the content and intent of the message. Do not stop at the most obvious category.

2.  **Predefined Categories and Their Meanings:**
    * `quality_and_safety_concerns`: Concerns about standards, effectiveness, potential harm, or safety aspects.
    * `specialized_cleaning_services`: Mentions cleaning products, methods, or requirements that are sensitive or unique (e.g., delicate surfaces, pet-friendly).
    * `sustainability_and_environmental_practices`: Related to energy efficiency, eco-friendly products, or environmental impact.
    * `general_inquiries`: Broad requests for information, advice, or deeper understanding, not tied to an immediate problem.

3.  **Reasoning Process:**
    * Read the entire message carefully.
    * Look for keywords mapping to categories (e.g., "delicate surfaces" -> `specialized_cleaning_services`).
    * Consider the sender's motivation.
    * Ensure you can articulate *why* a category applies based on explicit text.

4.  **Output Format:**
    * `reasoning`: Provide a detailed explanation of why each identified category applies.
    * `categories`: A JSON-formatted list of strings from the predefined list.

**Important Considerations:**
* A single message can fall into multiple categories.
* An "inquiry" about a specific topic should be categorized as both `general_inquiries` and the specific topic.
* Concerns about cleaning products on sensitive environments often indicate both `specialized_cleaning_services` and `sustainability_and_environmental_practices` or `quality_and_safety_concerns`."""

    message: str = dspy.InputField()
    categories: List[Literal["emergency_repair_services", "routine_maintenance_requests", "quality_and_safety_concerns", "specialized_cleaning_services", "general_inquiries", "sustainability_and_environmental_practices", "training_and_support_requests", "cleaning_services_scheduling", "customer_feedback_and_complaints", "facility_management_issues"]] = dspy.OutputField()

# %%
class OptimizedFacilitySupportAnalyzerMM(dspy.Module):
    def __init__(self):
        self.urgency_module = dspy.ChainOfThought(OptimizedFacilitySupportAnalyzerUrgency)
        self.sentiment_module = dspy.ChainOfThought(OptimizedFacilitySupportAnalyzerSentiment)
        self.categories_module = dspy.ChainOfThought(OptimizedFacilitySupportAnalyzerCategories)

    def forward(self, message: str):
        urgency = self.urgency_module(message=message)
        sentiment = self.sentiment_module(message=message)
        categories = self.categories_module(message=message)

        return dspy.Prediction(
            urgency=urgency.urgency,
            sentiment=sentiment.sentiment,
            categories=categories.categories
        )

optimized_program = OptimizedFacilitySupportAnalyzerMM()

# %%
import dspy
evaluate = dspy.Evaluate(
    devset=test_set,
    metric=metric,
    num_threads=5,
    display_table=True,
    display_progress=True
)

evaluate(optimized_program)
# Out:
# Average Metric: 190.77 / 226 (84.4%):  66%|██████▌   | 225/340 [01:16<00:04, 28.45it/s]
# GEPA Optimization:  13%|█▎        | 180/1355 [04:02<26:25,  1.35s/rollouts]
# Average Metric: 197.17 / 235 (83.9%):  69%|██████▉   | 235/340 [01:16<00:04, 25.71it/s]
# Average Metric: 286.57 / 340 (84.3%): 100%|██████████| 340/340 [01:19<00:00,  4.30it/s]
# 2026/07/08 20:41:54 INFO dspy.evaluate.evaluate: Average Metric: 286.56666666666666 / 340 (84.3%)
#                                                                    message  \
# 0    Hey ProCare Support Team, Hope you all are doing great! My name is...
# 1    Hey ProCare Team, Hope you’re all doing well! My name’s Jake, and ...
# 2    Subject: Assistance Needed for HVAC Maintenance Hi [Receiver], I h...
# 3    Subject: A Green Inquiry from a Bill Maher Enthusiast Hey ProCare ...
# 4    Subject: Inquiry on Sustainability Practices Dear ProCare Facility...
# ..                                                                     ...
# 335  Subject: Inquiry About Your Eco-Friendly Practices Dear ProCare Fa...
# 336  Subject: Assistance Needed for Facility Management Issue Dear ProC...
# 337  Subject: Request for Training and Support Hi ProCare Support Team,...
# 338  Subject: Concerns About Studio Maintenance and Rent Increase Dear ...
# 339  Subject: Feedback on Recent Maintenance Service Dear ProCare Suppo...
#
#                                                                     answer  \
# 0    {"categories": {"routine_maintenance_requests": false, "customer_f...
# 1    {"categories": {"routine_maintenance_requests": true, "customer_fe...
# 2    {"categories": {"routine_maintenance_requests": true, "customer_fe...
# 3    {"categories": {"routine_maintenance_requests": false, "customer_f...
# 4    {"categories": {"routine_maintenance_requests": false, "customer_f...
# ..                                                                     ...
# 335  {"categories": {"routine_maintenance_requests": false, "customer_f...
# 336  {"categories": {"routine_maintenance_requests": false, "customer_f...
# 337  {"categories": {"routine_maintenance_requests": false, "customer_f...
# 338  {"categories": {"routine_maintenance_requests": true, "customer_fe...
# 339  {"categories": {"routine_maintenance_requests": true, "customer_fe...
#
#     urgency sentiment  \
# 0       low  positive
# 1    medium  positive
# 2    medium   neutral
# 3       low  positive
# 4       low   neutral
# ..      ...       ...
# 335     low   neutral
# 336  medium   neutral
# 337     low  positive
# 338  medium   neutral
# 339  medium   neutral
#
#                                                                 categories  \
# 0          [sustainability_and_environmental_practices, general_inquiries]
# 1    [emergency_repair_services, routine_maintenance_requests, quality_...
# 2    [routine_maintenance_requests, facility_management_issues, general...
# 3          [sustainability_and_environmental_practices, general_inquiries]
# 4          [sustainability_and_environmental_practices, general_inquiries]
# ..                                                                     ...
# 335  [sustainability_and_environmental_practices, specialized_cleaning_...
# 336                        [facility_management_issues, general_inquiries]
# 337                     [training_and_support_requests, general_inquiries]
# 338  [routine_maintenance_requests, quality_and_safety_concerns, custom...
# 339  [customer_feedback_and_complaints, facility_management_issues, rou...
#
#          metric
# 0    ✔️ [0.967]
# 1    ✔️ [0.900]
# 2    ✔️ [0.933]
# 3    ✔️ [0.967]
# 4    ✔️ [0.967]
# ..          ...
# 335  ✔️ [1.000]
# 336  ✔️ [0.633]
# 337  ✔️ [0.967]
# 338  ✔️ [0.967]
# 339  ✔️ [0.933]
#
# [340 rows x 6 columns]
# EvaluationResult(score=84.28, results=<list of 340 results>)

# %% [markdown]
# # Actividades
#
# ## Actividad 1
#
# ### Pregunta 1 (1.33 puntos)
#
# Una de las dificultades de trabajar con secuencias de tamano muy grande (decenas de miles o cientos de miles de tokens) es que los modelos comienzan a presentar problemas y disminuye fuertemente su capacidad de utilizar el contenido en ese contexto.
#
# Investigue y describa otros 2 problemas relacionados a utilizar contextos muy grandes (Ayuda: Estos estan relacionados entre si y el uso de tecnicas de atencion tipo sparse o atencion tipo lineal son utilizadas como mitigacion. No es necesario investigar sobre esta tecnicas, es solo para facilitar su busqueda). Un par de oraciones es suficiente por problema.
#
# ### Pregunta 2 (0.66 puntos)
#
# Modelos como los de la familia Qwen 3.5 o Gemma 4 son de tipo hibrido, son capaces de generar con trazas de razonamiento (texto entre las etiquetas _\<think\>\<\/think\>_ antes de la respuesta final presentada al usuario), o saltandose la etapa de razonamiento y generando la respuesta final directamente.
#
# **Cual es la utilidad de poder deshabilitar la generacion con modo de razonamiento?**

# %% [markdown]
# ## Actividad 2
#
# Busque sobre cómo utilizar el modelo _Qwen/Qwen3-VL-2B-Thinking_ para trabajar con texto e imágenes. Luego utilice este modelo para:
#   - Generar una descripción de la imágen _sample-food.jpeg_
#   - Generar _bounding boxes_ (extracción de regiones) de los objetos en la imágen _sample-food.jpeg_ (Ayuda: Puede utilizar la siguiente instrucción _Generate bounding boxes for the objects in the image._).
#   - De la imágen _boleta.png_ extraer número de boleta, artículos vendidos, unidades de cada artículo vendido, precio unitario, fecha de venta, y estructurar estos valores en un JSON (la salida del modelo debe contener una sección de texto con estructura JSON).
#
# (1,33 puntos cada una)
#
#   Para la extracción de _bounding boxes_, dibuje los rectángulos sobre la imágen. A continuación se incluye código para realizar esto.

# %%
# Descarga imágenes

# !gdown 1AfQ72ybSTr5oUqhsyyVNwBGbBsna74b8
# !gdown 12HmBb4GqpzkuIoe8kl8mPp04qgkZOirj
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1AfQ72ybSTr5oUqhsyyVNwBGbBsna74b8
# To: /content/boleta.png
# 100% 126k/126k [00:00<00:00, 4.06MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12HmBb4GqpzkuIoe8kl8mPp04qgkZOirj
# To: /content/sample-food.jpeg
# 100% 537k/537k [00:00<00:00, 8.79MB/s]

# %%
import json
import random
import io
import ast
from io import BytesIO
from PIL import Image, ImageDraw, ImageFont
from PIL import ImageColor
import xml.etree.ElementTree as ET

additional_colors = [colorname for (colorname, colorcode) in ImageColor.colormap.items()]

def parse_json(json_output):
    # Parsing out the markdown fencing
    lines = json_output.splitlines()
    for i, line in enumerate(lines):
        if line == "```json":
            json_output = "\n".join(lines[i+1:])  # Remove everything before "```json"
            json_output = json_output.split("```")[0]  # Remove everything after the closing "```"
            break  # Exit the loop once "```json" is found
    return json_output


def plot_bounding_boxes(im, bounding_boxes):
    """
    Plots bounding boxes on an image with markers for each a name, using PIL, normalized coordinates, and different colors.

    Args:
        img_path: The path to the image file.
        bounding_boxes: A list of bounding boxes containing the name of the object
         and their positions in normalized [y1 x1 y2 x2] format.
    """

    # Load the image
    img = im
    width, height = img.size
    print(img.size)
    # Create a drawing object
    draw = ImageDraw.Draw(img)

    # Define a list of colors
    colors = [
    'red',
    'green',
    'blue',
    'yellow',
    'orange',
    'pink',
    'purple',
    'brown',
    'gray',
    'beige',
    'turquoise',
    'cyan',
    'magenta',
    'lime',
    'navy',
    'maroon',
    'teal',
    'olive',
    'coral',
    'lavender',
    'violet',
    'gold',
    'silver',
    ] + additional_colors

    if not isinstance(bounding_boxes, list):
      json_output = [bounding_boxes]

    # Iterate over the bounding boxes
    for i, bounding_box in enumerate(bounding_boxes):
      # Select a color from the list
      color = colors[i % len(colors)]

      # Convert normalized coordinates to absolute coordinates
      abs_y1 = int(bounding_box["bbox_2d"][1] / 1000 * height)
      abs_x1 = int(bounding_box["bbox_2d"][0] / 1000 * width)
      abs_y2 = int(bounding_box["bbox_2d"][3] / 1000 * height)
      abs_x2 = int(bounding_box["bbox_2d"][2] / 1000 * width)

      if abs_x1 > abs_x2:
        abs_x1, abs_x2 = abs_x2, abs_x1

      if abs_y1 > abs_y2:
        abs_y1, abs_y2 = abs_y2, abs_y1

      # Draw the bounding box
      draw.rectangle(
          ((abs_x1, abs_y1), (abs_x2, abs_y2)), outline=color, width=3
      )

      # Draw the text
      if "label" in bounding_box:
        draw.text((abs_x1 + 8, abs_y1 + 6), bounding_box["label"], fill=color)

    # Display the image
    img.show()

# %%
boxes_text = """```json
[{"bbox_2d": [232, 100, 709, 370], "label": "soup"}]
```
"""
image = Image.open("sample-food.jpeg")
image.thumbnail([640,640], Image.Resampling.LANCZOS)
plot_bounding_boxes(image, json.loads(parse_json(boxes_text)))

image
# Out:
# (480, 640)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x640>

# %% [markdown]
# 1. Generar una descripción de la imágen sample-food.jpeg

# %% [markdown]
# 2. Generar bounding boxes (extracción de regiones) de los objetos en la imágen sample-food.jpeg (Aquí es suficiente con imprimir la respuesta del modelo y copiar y pegar el JSON generado en la funcion entregada)

# %% [markdown]
# 3. De la imágen boleta.png extraer número de boleta, artículos vendidos, unidades de cada artículo vendido, precio unitario, fecha de venta, y estructurar estos valores en un JSON (la salida del modelo debe contener una sección de texto con estructura JSON).
